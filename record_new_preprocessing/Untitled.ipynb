# %%
import string
import numpy as np
import matplotlib.pyplot as plt
import os
from prettytable import PrettyTable

# %%
dir1 = 'bagging_cold_start_positives_100_clean_data_size_50_additional_data_size_2000/' + \
        '[[32, 5, 5], [32, 5, 5], [32, 5, 5], [256]]/' + \
        'bagging_threshold_0.85_add_criterion_80_minimum_additional_size_50_lr_0.0003/seed_10/'
precision_file = open(dir1 + 'precision_file.txt')

line = precision_file.readlines()
precision = np.zeros((10, 10))
number = np.zeros((10, 10))
for i in range(10):
    precision[:, i] = [float(x) for x in line[i*2].replace('[', '').replace(']', '').replace('\n', '').split(',')]
    number[:, i] = [int(x) for x in line[i*2+1].replace('[', '').replace(']', '').replace('\n', '').split(',')]

print(np.around(precision, decimals=3))
print(number)
# Out:
# [[0.663 0.613 0.432 0.333 0.325 0.558 0.607 0.696 0.659 0.543]
#  [0.631 0.65  0.44  0.332 0.333 0.551 0.595 0.687 0.7   0.559]
#  [0.64  0.645 0.463 0.344 0.388 0.59  0.619 0.756 0.755 0.6  ]
#  [0.637 0.647 0.455 0.35  0.4   0.607 0.675 0.795 0.811 0.622]
#  [0.638 0.652 0.454 0.333 0.435 0.617 0.713 0.838 0.827 0.638]
#  [0.631 0.641 0.442 0.334 0.386 0.618 0.737 0.859 0.851 0.645]
#  [0.635 0.647 0.446 0.322 0.363 0.601 0.725 0.863 0.844 0.664]
#  [0.64  0.65  0.451 0.324 0.386 0.593 0.672 0.878 0.858 0.668]
#  [0.635 0.657 0.448 0.328 0.372 0.586 0.65  0.835 0.859 0.683]
#  [0.644 0.655 0.435 0.327 0.384 0.579 0.649 0.828 0.841 0.688]]
# [[1400. 1662.  655. 1055.  332. 1422.  608. 1402. 1854. 1932.]
#  [1906. 1450.  916. 1300.  685. 1422.  847. 1455. 1993. 2000.]
#  [1909. 1607.  696.  979.  410.  945.  620. 1094. 1642. 1464.]
#  [1911. 1727.  972.  765.  240.  765.  510.  930. 1222. 1261.]
#  [1894. 1779. 1023. 1077.  186.  595.  383.  728. 1058. 1043.]
#  [1932. 1899. 1061. 1140.  422.  571.  304.  708.  850.  894.]
#  [1895. 1943. 1119. 1210.  454.  862.  269.  641.  848.  748.]
#  [1932. 1937. 1073. 1208.  456.  954.  574.  533.  705.  698.]
#  [1897. 1939. 1130. 1210.  473.  967.  652.  869.  644.  606.]
#  [1909. 1947. 1174. 1235.  489. 1021.  684.  937. 1096.  541.]]

# %%
dir1 = 'bagging_cold_start_positives_200_clean_data_size_100_additional_data_size_2000/' + \
        '[[32, 5, 5], [32, 5, 5], [32, 5, 5], [256]]/' + \
        'bagging_threshold_0.85_add_criterion_80_minimum_additional_size_50_lr_0.0003/seed_10/'
precision_file = open(dir1 + 'precision_file.txt')

line = precision_file.readlines()
precision = np.zeros((10, 4))
number = np.zeros((10, 4))
for i in range(4):
    precision[:, i] = [float(x) for x in line[i*2].replace('[', '').replace(']', '').replace('\n', '').split(',')]
    number[:, i] = [int(x) for x in line[i*2+1].replace('[', '').replace(']', '').replace('\n', '').split(',')]

print(np.around(precision, decimals=3))
print(number)
# Out:
# [[0.63  0.706 0.448 0.353]
#  [0.65  0.746 0.512 0.375]
#  [0.651 0.746 0.53  0.411]
#  [0.652 0.75  0.519 0.419]
#  [0.652 0.754 0.509 0.393]
#  [0.655 0.746 0.519 0.383]
#  [0.657 0.754 0.52  0.386]
#  [0.654 0.753 0.526 0.382]
#  [0.655 0.752 0.522 0.388]
#  [0.654 0.756 0.522 0.383]]
# [[2000. 2000. 1655. 2000.]
#  [2000. 1875.  997. 1438.]
#  [2000. 2000.  744. 1012.]
#  [2000. 2000. 1096.  805.]
#  [2000. 2000. 1145. 1214.]
#  [2000. 2000. 1212. 1354.]
#  [2000. 2000. 1174. 1389.]
#  [2000. 2000. 1199. 1335.]
#  [2000. 2000. 1204. 1372.]
#  [2000. 2000. 1215. 1326.]]

# %%
dir1 = 'bagging_cold_start_positives_500_clean_data_size_250_additional_data_size_2000/' + \
        '[[32, 5, 5], [32, 5, 5], [32, 5, 5], [256]]/' + \
        'bagging_threshold_0.85_add_criterion_80_minimum_additional_size_50_lr_0.0003/seed_10/'
precision_file = open(dir1 + 'precision_file.txt')

line = precision_file.readlines()
precision = np.zeros((10, 2))
number = np.zeros((10, 2))
for i in range(2):
    precision[:, i] = [float(x) for x in line[i*2].replace('[', '').replace(']', '').replace('\n', '').split(',')]
    number[:, i] = [int(x) for x in line[i*2+1].replace('[', '').replace(']', '').replace('\n', '').split(',')]

print(np.around(precision, decimals=3))
print(number)
# Out:
# [[0.691 0.798]
#  [0.714 0.83 ]
#  [0.724 0.831]
#  [0.713 0.842]
#  [0.724 0.846]
#  [0.718 0.846]
#  [0.723 0.848]
#  [0.722 0.846]
#  [0.722 0.85 ]
#  [0.72  0.854]]
# [[2000. 2000.]
#  [2000. 2000.]
#  [2000. 2000.]
#  [2000. 2000.]
#  [2000. 2000.]
#  [2000. 2000.]
#  [2000. 2000.]
#  [2000. 2000.]
#  [2000. 2000.]
#  [2000. 2000.]]

# %%
dir1 = 'bagging_cold_start_positives_1000_clean_data_size_500_additional_data_size_2000/' + \
        '[[32, 5, 5], [32, 5, 5], [32, 5, 5], [256]]/' + \
        'bagging_threshold_0.85_add_criterion_80_minimum_additional_size_50_lr_0.0003/seed_10/'
precision_file = open(dir1 + 'precision_file.txt')

line = precision_file.readlines()
precision = np.zeros((10, 1))
number = np.zeros((10, 1))
for i in range(1):
    precision[:, i] = [float(x) for x in line[i*2].replace('[', '').replace(']', '').replace('\n', '').split(',')]
    number[:, i] = [int(x) for x in line[i*2+1].replace('[', '').replace(']', '').replace('\n', '').split(',')]

print(np.around(precision, decimals=3))
print(number)
# Out:
# [[0.804]
#  [0.821]
#  [0.832]
#  [0.83 ]
#  [0.83 ]
#  [0.83 ]
#  [0.828]
#  [0.831]
#  [0.835]
#  [0.83 ]]
# [[2000.]
#  [2000.]
#  [2000.]
#  [2000.]
#  [2000.]
#  [2000.]
#  [2000.]
#  [2000.]
#  [2000.]
#  [2000.]]

# %%
dirs1 = 'bagging_renew_models_PU/noise_0.8_clean_data_size_50_additional_data_size_2000/'
dirs2 = 'bagging_without_renew_models_PU/noise_0.8_clean_data_size_50_additional_data_size_2000/'

dirs3 = 'bagging_renew_models_PU/noise_0.5_clean_data_size_50_additional_data_size_2000/'
dirs4 = 'bagging_without_renew_models_PU/noise_0.5_clean_data_size_50_additional_data_size_2000/'

# %%
benchmark_folder = 'benchmark/noise_0.8_lr_0.0003/'
benchmark_accuracy = np.zeros((5, 50))
for index in range(5):
    file = open(benchmark_folder + 'test' + str(index) + '/file_benchmark.txt')
    line = file.readlines()
    benchmark_accuracy[index] = [float(x) for x in line[3].replace('[', '').replace(']', '').replace('\n', '').split(',')]
benchmark_accuracy = np.mean(benchmark_accuracy, axis=0)
print(benchmark_accuracy.shape)
print(benchmark_accuracy)
# Out:
# (50,)
# [0.2312  0.27626 0.31568 0.341   0.35574 0.377   0.35794 0.34056 0.30786
#  0.2919  0.26636 0.24978 0.23444 0.21894 0.21116 0.20706 0.19768 0.1984
#  0.1865  0.1844  0.18622 0.18286 0.17642 0.17468 0.1732  0.17136 0.172
#  0.169   0.17214 0.16902 0.17074 0.1665  0.17066 0.1685  0.1666  0.1683
#  0.16238 0.16812 0.16538 0.16792 0.16262 0.16652 0.1641  0.16222 0.16284
#  0.16472 0.16486 0.16408 0.1638  0.1622 ]

# %%
benchmark_folder2 = 'benchmark/noise_0.5_lr_0.0003/'
benchmark_accuracy2 = np.zeros((5, 50))
for index in range(5):
    file = open(benchmark_folder2 + 'test' + str(index) + '/file_benchmark.txt')
    line = file.readlines()
    benchmark_accuracy2[index] = [float(x) for x in line[3].replace('[', '').replace(']', '').replace('\n', '').split(',')]
benchmark_accuracy2 = np.mean(benchmark_accuracy2, axis=0)
print(benchmark_accuracy2.shape)
print(benchmark_accuracy2)
# Out:
# (50,)
# [0.43246 0.50754 0.5495  0.56208 0.5881  0.59182 0.59738 0.60154 0.58674
#  0.59024 0.57878 0.56754 0.5536  0.5518  0.5382  0.52784 0.51528 0.50428
#  0.49892 0.48896 0.4796  0.47686 0.46374 0.459   0.45282 0.45092 0.45204
#  0.44468 0.44654 0.44248 0.4371  0.44132 0.43498 0.43406 0.43146 0.43138
#  0.43476 0.43238 0.43162 0.42732 0.42764 0.42982 0.43192 0.42672 0.42472
#  0.42284 0.42498 0.42346 0.41984 0.42314]

# %%
# dirs1

for threshold in [0.8, 0.85, 0.9, 0.95]:
    for criterion in [75, 90]:
        folder = dirs1 + 'bagging_threshold_' + str(threshold) + '_add_criterion_' + str(criterion) + \
                '_minimum_additional_size_50/seed_10/'
        precision_file = open(folder + 'precision_file.txt')
        
        line = precision_file.readlines()
        precision = np.zeros((10, 10))
        number = np.zeros((10, 10))
        for i in range(10):
            precision[:, i] = [float(x) for x in line[i*2].replace('[', '').replace(']', '').replace('\n', '').split(',')]
            number[:, i] = [int(x) for x in line[i*2+1].replace('[', '').replace(']', '').replace('\n', '').split(',')]
            
        print(np.around(precision, decimals=3))
        print(number)
        print(folder)
        lambda_list = [0.3, 0.4, 0.5, 0.6, 0.7, 0.8]
        student_accuracy = np.zeros((6, 5, 50))
        teacher_accuracy = np.zeros((5, 50))
        for lambda_i in range(6):
            for index in range(5):
                student_file = open(folder + 'file_student_' + str(index) + '.txt')
                teacher_file = open(folder + 'file_teacher_' + str(index) + '.txt')

                line = student_file.readlines()
                student_accuracy[lambda_i, index, :] = [float(x) for x in line[lambda_i*4+3].replace('[', '').replace(']', '').replace('\n', '').split(',')]
                
                line = teacher_file.readlines()
                accuracy = [float(x) for x in line[3].replace('[', '').replace(']', '').replace('\n', '').split(',')]
                if len(accuracy) < 50:
                    accuracy = accuracy + [accuracy[-1]]*(50-len(accuracy))
                teacher_accuracy[index, :] = accuracy
        student_accuracy = np.mean(student_accuracy, axis=1)
        teacher_accuracy = np.mean(teacher_accuracy, axis=0)
        
        plt.figure(1) # 创建图表1
        plt.figure(figsize=(10,6))
        plt.plot(np.arange(50)+1, benchmark_accuracy, '--', label='benchmark')
        plt.plot(np.arange(50)+1, teacher_accuracy, ':', label='teacher')
        for lambda_i in range(6):
            plt.plot(np.arange(50)+1, student_accuracy[lambda_i], label='student, $\lambda$=%.1f'%lambda_list[lambda_i])
        
        plt.legend()
        plt.grid()
        plt.ylim(0,1)
        plt.xlabel('epoch')
        plt.ylabel('accuracy')
        plt.title('confident threshold %.2f, adding criterion %d'%(threshold, criterion))

        dirs = 'figure/' + dirs1
        if not os.path.exists(dirs):
            os.makedirs(dirs)
        plt.savefig(dirs + 'bagging_threshold_' + str(threshold) + '_add_criterion_' + str(criterion) + '_minimum_additional_size_50.png')
        plt.show()
        
        table = PrettyTable(['line', 'Maximum', 'Last'])
        table.add_row(['benchmark', np.round(np.max(benchmark_accuracy), decimals=3), np.round(benchmark_accuracy[-1], decimals=3)])
        table.add_row(['teacher', np.round(np.max(teacher_accuracy), decimals=3), np.round(teacher_accuracy[-1], decimals=3)])
        for i in range(6):
            table.add_row(['student, λ='+str(lambda_list[i]), np.round(np.max(student_accuracy[i]), decimals=3), np.round(student_accuracy[i, -1], decimals=3)])
        print(table)
# Out:
# [[0.626 0.6   0.373 0.331 0.286 0.518 0.515 0.636 0.662 0.552]
#  [0.633 0.608 0.38  0.327 0.264 0.514 0.491 0.626 0.672 0.55 ]
#  [0.637 0.622 0.383 0.328 0.295 0.524 0.515 0.628 0.652 0.558]
#  [0.633 0.622 0.395 0.336 0.282 0.522 0.518 0.63  0.658 0.551]
#  [0.637 0.625 0.388 0.324 0.271 0.516 0.521 0.628 0.652 0.534]
#  [0.638 0.625 0.385 0.32  0.308 0.514 0.496 0.624 0.647 0.547]
#  [0.636 0.622 0.389 0.321 0.302 0.513 0.479 0.628 0.654 0.549]
#  [0.634 0.624 0.386 0.322 0.297 0.518 0.482 0.619 0.65  0.54 ]
#  [0.636 0.62  0.393 0.324 0.303 0.518 0.49  0.632 0.66  0.551]
#  [0.632 0.622 0.39  0.322 0.3   0.52  0.482 0.636 0.708 0.532]]
# [[2000. 2000. 1694. 2000. 1662. 2000. 1330. 2000. 2000. 2000.]
#  [2000. 2000. 1597. 2000. 1669. 2000. 1696. 2000. 2000. 2000.]
#  [2000. 2000. 1568. 2000. 1525. 2000. 1459. 2000. 2000. 2000.]
#  [2000. 2000. 2000. 2000. 1607. 2000. 1506. 2000. 2000. 2000.]
#  [2000. 2000. 2000. 2000. 1655. 2000. 1268. 2000. 2000. 2000.]
#  [2000. 2000. 2000. 2000. 2000. 2000. 2000. 2000. 2000. 2000.]
#  [2000. 2000. 2000. 2000. 2000. 2000. 1679. 2000. 2000. 2000.]
#  [2000. 2000. 2000. 2000. 2000. 2000. 2000. 2000. 2000. 2000.]
#  [2000. 2000. 2000. 2000. 2000. 2000. 2000. 2000. 2000. 2000.]
#  [2000. 2000. 2000. 2000. 2000. 2000. 2000. 2000. 2000. 2000.]]
# bagging_renew_models_PU/noise_0.8_clean_data_size_50_additional_data_size_2000/bagging_threshold_0.8_add_criterion_75_minimum_additional_size_50/seed_10/
# +----------------+---------+-------+
# |      line      | Maximum |  Last |
# +----------------+---------+-------+
# |   benchmark    |  0.377  | 0.162 |
# |    teacher     |  0.385  | 0.381 |
# | student, λ=0.3 |  0.393  | 0.388 |
# | student, λ=0.4 |  0.396  | 0.387 |
# | student, λ=0.5 |  0.402  | 0.382 |
# | student, λ=0.6 |  0.406  | 0.365 |
# | student, λ=0.7 |   0.41  | 0.346 |
# | student, λ=0.8 |  0.414  | 0.305 |
# +----------------+---------+-------+
# [[0.742 0.658 0.44  0.375 0.322 0.623 0.732 0.778 0.708 0.573]
#  [0.676 0.683 0.459 0.356 0.284 0.627 0.79  0.755 0.727 0.566]
#  [0.675 0.647 0.427 0.354 0.328 0.596 0.744 0.739 0.688 0.568]
#  [0.678 0.634 0.422 0.344 0.263 0.614 0.757 0.757 0.728 0.558]
#  [0.668 0.642 0.419 0.318 0.33  0.617 0.685 0.774 0.698 0.567]
#  [0.671 0.636 0.419 0.318 0.332 0.636 0.691 0.776 0.673 0.567]
#  [0.673 0.645 0.414 0.323 0.341 0.566 0.651 0.781 0.708 0.577]
#  [0.678 0.639 0.42  0.326 0.32  0.571 0.553 0.793 0.71  0.582]
#  [0.666 0.646 0.425 0.322 0.345 0.577 0.567 0.729 0.71  0.59 ]
#  [0.671 0.635 0.413 0.327 0.338 0.572 0.558 0.718 0.711 0.59 ]]
# [[ 955. 1079.  393.  541.  214.  905.  336.  952. 1384. 1488.]
#  [1619. 1060.  503.  568.  176.  848.  200.  936. 1265. 1391.]
#  [1658. 1748.  480.  792.  323. 1036.  312. 1155. 1462. 1506.]
#  [1628. 1772. 1140.  707.  358.  982.  247. 1041. 1267. 1399.]
#  [1662. 1714. 1092. 1477.  176.  898.  410. 1032. 1482. 1491.]
#  [1687. 1730. 1102. 1475. 1033.  785.  275.  995. 1483. 1565.]
#  [1592. 1716. 1173. 1441. 1010. 1428.  482. 1020. 1371. 1498.]
#  [1612. 1757. 1168. 1418. 1093. 1412. 1268.  876. 1107. 1376.]
#  [1649. 1718. 1173. 1431.  936. 1382. 1233. 1495. 1333. 1323.]
#  [1668. 1782. 1131. 1400. 1039. 1389. 1261. 1528. 1930. 1072.]]
# bagging_renew_models_PU/noise_0.8_clean_data_size_50_additional_data_size_2000/bagging_threshold_0.8_add_criterion_90_minimum_additional_size_50/seed_10/
# +----------------+---------+-------+
# |      line      | Maximum |  Last |
# +----------------+---------+-------+
# |   benchmark    |  0.377  | 0.162 |
# |    teacher     |  0.389  | 0.389 |
# | student, λ=0.3 |  0.398  | 0.394 |
# | student, λ=0.4 |  0.402  | 0.391 |
# | student, λ=0.5 |  0.406  | 0.386 |
# | student, λ=0.6 |  0.409  | 0.372 |
# | student, λ=0.7 |  0.415  | 0.352 |
# | student, λ=0.8 |  0.423  | 0.312 |
# +----------------+---------+-------+
# [[0.652 0.602 0.416 0.347 0.291 0.53  0.613 0.684 0.636 0.545]
#  [0.63  0.592 0.392 0.346 0.263 0.52  0.591 0.658 0.637 0.55 ]
#  [0.63  0.616 0.393 0.327 0.293 0.535 0.613 0.686 0.65  0.556]
#  [0.628 0.614 0.381 0.354 0.282 0.529 0.6   0.668 0.656 0.546]
#  [0.632 0.608 0.386 0.323 0.286 0.525 0.589 0.674 0.656 0.542]
#  [0.631 0.612 0.382 0.317 0.288 0.532 0.572 0.679 0.65  0.55 ]
#  [0.63  0.611 0.376 0.318 0.288 0.522 0.582 0.663 0.656 0.55 ]
#  [0.635 0.615 0.383 0.32  0.288 0.528 0.487 0.672 0.652 0.54 ]
#  [0.632 0.61  0.386 0.32  0.282 0.518 0.475 0.636 0.652 0.552]
#  [0.628 0.615 0.38  0.318 0.292 0.523 0.48  0.635 0.704 0.534]]
# [[1622. 2000.  867. 1237. 1015. 1658.  768. 1442. 2000. 2000.]
#  [2000. 2000.  883. 1322.  562. 2000.  817. 1658. 2000. 2000.]
#  [2000. 2000.  949. 1506.  687. 1726.  746. 1471. 2000. 2000.]
#  [2000. 2000. 2000. 1252.  776. 1745.  702. 1595. 2000. 2000.]
#  [2000. 2000. 2000. 2000.  853. 1882.  896. 1591. 1938. 2000.]
#  [2000. 2000. 2000. 2000. 2000. 1804.  766. 1567. 2000. 1996.]
#  [2000. 2000. 2000. 2000. 2000. 2000.  693. 1669. 2000. 2000.]
#  [2000. 2000. 2000. 2000. 2000. 2000. 1940. 1559. 2000. 2000.]
#  [2000. 2000. 2000. 2000. 2000. 2000. 2000. 2000. 2000. 2000.]
#  [2000. 2000. 2000. 2000. 2000. 2000. 1988. 2000. 2000. 2000.]]
# bagging_renew_models_PU/noise_0.8_clean_data_size_50_additional_data_size_2000/bagging_threshold_0.85_add_criterion_75_minimum_additional_size_50/seed_10/
# +----------------+---------+-------+
# |      line      | Maximum |  Last |
# +----------------+---------+-------+
# |   benchmark    |  0.377  | 0.162 |
# |    teacher     |  0.387  | 0.385 |
# | student, λ=0.3 |  0.395  | 0.393 |
# | student, λ=0.4 |  0.398  | 0.388 |
# | student, λ=0.5 |  0.403  | 0.384 |
# | student, λ=0.6 |  0.407  |  0.37 |
# | student, λ=0.7 |   0.41  | 0.347 |
# | student, λ=0.8 |  0.415  | 0.309 |
# +----------------+---------+-------+
# [[0.773 0.673 0.433 0.376 0.304 0.654 0.824 0.837 0.747 0.617]
#  [0.711 0.713 0.453 0.366 0.317 0.677 0.827 0.865 0.753 0.595]
#  [0.7   0.663 0.396 0.35  0.297 0.649 0.845 0.857 0.768 0.621]
#  [0.702 0.664 0.444 0.363 0.324 0.657 0.773 0.807 0.737 0.614]
#  [0.717 0.663 0.449 0.338 0.34  0.655 0.748 0.855 0.738 0.595]
#  [0.708 0.651 0.435 0.333 0.297 0.677 0.83  0.847 0.72  0.595]
#  [0.696 0.661 0.438 0.338 0.324 0.614 0.815 0.873 0.777 0.585]
#  [0.728 0.665 0.442 0.34  0.301 0.611 0.682 0.845 0.742 0.619]
#  [0.718 0.664 0.432 0.332 0.295 0.601 0.668 0.777 0.761 0.594]
#  [0.719 0.655 0.425 0.315 0.312 0.609 0.655 0.776 0.747 0.606]]
# [[ 594.  899.  252.  457.   92.  612.  148.  681.  818.  950.]
#  [1249.  741.  214.  399.   63.  507.   98.  600.  850.  929.]
#  [1269. 1346.  197.  494.   64.  721.  142.  624.  514.  782.]
#  [1230. 1369.  709.  476.   74.  586.   75.  831.  669.  964.]
#  [1221. 1370.  680. 1055.   50.  583.  135.  629.  779.  948.]
#  [1241. 1427.  733. 1050.  634.  508.  147.  608.  888.  990.]
#  [1316. 1399.  690.  957.  608. 1024.  135.  565.  606. 1144.]
#  [1144. 1390.  633. 1013.  654. 1038.  620.  634.  761. 1087.]
#  [1160. 1377.  764. 1104.  594. 1094.  677. 1173.  748.  977.]
#  [1208. 1418.  778. 1029.  503. 1020.  715. 1199. 1523.  963.]]
# bagging_renew_models_PU/noise_0.8_clean_data_size_50_additional_data_size_2000/bagging_threshold_0.85_add_criterion_90_minimum_additional_size_50/seed_10/
# +----------------+---------+-------+
# |      line      | Maximum |  Last |
# +----------------+---------+-------+
# |   benchmark    |  0.377  | 0.162 |
# |    teacher     |  0.394  | 0.392 |
# | student, λ=0.3 |  0.404  | 0.399 |
# | student, λ=0.4 |  0.409  | 0.395 |
# | student, λ=0.5 |   0.41  | 0.388 |
# | student, λ=0.6 |  0.413  | 0.374 |
# | student, λ=0.7 |  0.421  |  0.35 |
# | student, λ=0.8 |  0.424  | 0.312 |
# +----------------+---------+-------+
# [[0.716 0.621 0.415 0.345 0.291 0.57  0.683 0.752 0.672 0.561]
#  [0.643 0.641 0.418 0.345 0.204 0.583 0.751 0.762 0.683 0.561]
#  [0.646 0.618 0.405 0.347 0.32  0.558 0.708 0.735 0.69  0.566]
#  [0.64  0.612 0.402 0.343 0.278 0.564 0.708 0.759 0.68  0.569]
#  [0.648 0.619 0.39  0.315 0.28  0.576 0.695 0.762 0.67  0.578]
#  [0.641 0.614 0.403 0.322 0.291 0.571 0.729 0.769 0.68  0.56 ]
#  [0.644 0.608 0.403 0.321 0.283 0.522 0.704 0.756 0.714 0.567]
#  [0.646 0.616 0.395 0.317 0.287 0.523 0.548 0.781 0.65  0.567]
#  [0.645 0.606 0.388 0.319 0.29  0.521 0.539 0.685 0.694 0.576]
#  [0.641 0.608 0.401 0.319 0.278 0.521 0.56  0.679 0.69  0.57 ]]
# [[ 950. 1360.  446.  629.  275. 1143.  249. 1045. 1437. 1661.]
#  [1881. 1266.  416.  652.  167. 1085.  189. 1031. 1225. 1507.]
#  [1815. 2000.  375.  637.  153. 1293.  212. 1149. 1203. 1584.]
#  [1851. 2000. 1269.  679.  205. 1148.  236. 1043. 1339. 1616.]
#  [1768. 2000. 1261. 1754.  246. 1176.  213. 1074. 1386. 1220.]
#  [1823. 2000. 1238. 1675. 1438. 1044.  203. 1041. 1357. 1718.]
#  [1825. 2000. 1248. 1615. 1430. 1886.  230. 1059. 1011. 1383.]
#  [1796. 2000. 1242. 1627. 1438. 1842. 1171. 1001. 1571. 1486.]
#  [1838. 2000. 1303. 1584. 1444. 1924. 1150. 1770. 1110. 1574.]
#  [1846. 2000. 1280. 1576. 1523. 1894. 1135. 1788. 2000. 1447.]]
# bagging_renew_models_PU/noise_0.8_clean_data_size_50_additional_data_size_2000/bagging_threshold_0.9_add_criterion_75_minimum_additional_size_50/seed_10/
# +----------------+---------+-------+
# |      line      | Maximum |  Last |
# +----------------+---------+-------+
# |   benchmark    |  0.377  | 0.162 |
# |    teacher     |  0.391  | 0.386 |
# | student, λ=0.3 |   0.4   | 0.395 |
# | student, λ=0.4 |  0.401  |  0.39 |
# | student, λ=0.5 |  0.406  | 0.383 |
# | student, λ=0.6 |  0.409  | 0.367 |
# | student, λ=0.7 |  0.414  | 0.347 |
# | student, λ=0.8 |  0.414  | 0.311 |
# +----------------+---------+-------+
# [[0.84  0.769 0.4   0.361 0.36  0.695 0.82  0.901 0.815 0.646]
#  [0.76  0.751 0.405 0.352 0.26  0.707 0.8   0.908 0.798 0.624]
#  [0.754 0.703 0.462 0.371 0.24  0.711 0.78  0.895 0.834 0.633]
#  [0.755 0.716 0.449 0.367 0.32  0.712 0.84  0.893 0.779 0.646]
#  [0.758 0.71  0.44  0.329 0.34  0.729 0.86  0.898 0.793 0.64 ]
#  [0.751 0.71  0.454 0.332 0.315 0.701 0.88  0.892 0.808 0.6  ]
#  [0.75  0.706 0.436 0.33  0.303 0.648 0.84  0.897 0.812 0.622]
#  [0.741 0.7   0.438 0.326 0.324 0.666 0.702 0.905 0.773 0.601]
#  [0.766 0.722 0.454 0.325 0.304 0.655 0.73  0.842 0.815 0.61 ]
#  [0.764 0.718 0.45  0.325 0.299 0.655 0.73  0.85  0.789 0.615]]
# [[ 319.  403.   50.  183.   50.  318.   50.  284.  356.  523.]
#  [ 830.  361.   79.  196.   50.  280.   50.  325.  307.  540.]
#  [ 862.  897.   52.  210.   50.  339.   50.  372.  314.  521.]
#  [ 829.  936.  352.  270.   50.  386.   50.  421.  390.  477.]
#  [ 830.  931.  468.  769.   50.  291.   50.  440.  377.  600.]
#  [ 836.  894.  412.  762.  359.  274.   50.  399.  396.  482.]
#  [ 865.  921.  367.  754.  350.  705.   50.  426.  336.  502.]
#  [ 876. 1015.  386.  733.  225.  662.  383.  348.  437.  546.]
#  [ 778.  873.  423.  716.  303.  713.  363.  825.  341.  598.]
#  [ 795.  900.  371.  782.  335.  687.  370.  825.  830.  488.]]
# bagging_renew_models_PU/noise_0.8_clean_data_size_50_additional_data_size_2000/bagging_threshold_0.9_add_criterion_90_minimum_additional_size_50/seed_10/
# +----------------+---------+-------+
# |      line      | Maximum |  Last |
# +----------------+---------+-------+
# |   benchmark    |  0.377  | 0.162 |
# |    teacher     |  0.391  | 0.386 |
# | student, λ=0.3 |   0.4   | 0.394 |
# | student, λ=0.4 |  0.404  |  0.39 |
# | student, λ=0.5 |  0.408  | 0.385 |
# | student, λ=0.6 |  0.412  |  0.37 |
# | student, λ=0.7 |  0.418  | 0.345 |
# | student, λ=0.8 |  0.418  | 0.304 |
# +----------------+---------+-------+
# [[0.788 0.717 0.393 0.348 0.26  0.658 0.88  0.894 0.73  0.586]
#  [0.715 0.748 0.43  0.34  0.34  0.675 0.9   0.894 0.755 0.609]
#  [0.725 0.667 0.414 0.325 0.36  0.685 0.88  0.877 0.798 0.617]
#  [0.72  0.668 0.425 0.34  0.3   0.676 0.8   0.882 0.803 0.61 ]
#  [0.729 0.673 0.416 0.313 0.3   0.667 0.82  0.893 0.786 0.602]
#  [0.717 0.677 0.414 0.305 0.223 0.694 0.72  0.89  0.785 0.611]
#  [0.72  0.67  0.432 0.312 0.245 0.599 0.82  0.894 0.833 0.593]
#  [0.727 0.676 0.431 0.31  0.218 0.595 0.649 0.88  0.772 0.595]
#  [0.716 0.673 0.414 0.312 0.222 0.601 0.667 0.794 0.762 0.604]
#  [0.726 0.662 0.428 0.314 0.233 0.605 0.651 0.807 0.743 0.588]]
# [[ 377.  527.  173.  336.   50.  535.   50.  404.  552.  585.]
#  [1107.  531.  107.  318.   50.  557.   50.  387.  428.  682.]
#  [1010. 1327.  116.  320.   50.  464.   50.  470.  312.  548.]
#  [1038. 1366.  624.  282.   50.  472.   50.  491.  335.  669.]
#  [ 985. 1350.  640.  995.   50.  427.   50.  391.  345.  593.]
#  [1045. 1303.  587.  963.  548.  392.   50.  417.  330.  627.]
#  [1051. 1347.  607.  918.  458. 1018.   50.  386.  234.  668.]
#  [1011. 1293.  559.  975.  528. 1059.  413.  399.  338.  630.]
#  [1071. 1381.  587.  984.  433. 1012.  430. 1045.  382.  649.]
#  [ 994. 1365.  577.  985.  519. 1009.  424. 1033. 1176.  588.]]
# bagging_renew_models_PU/noise_0.8_clean_data_size_50_additional_data_size_2000/bagging_threshold_0.95_add_criterion_75_minimum_additional_size_50/seed_10/
# +----------------+---------+-------+
# |      line      | Maximum |  Last |
# +----------------+---------+-------+
# |   benchmark    |  0.377  | 0.162 |
# |    teacher     |  0.383  | 0.383 |
# | student, λ=0.3 |  0.395  |  0.39 |
# | student, λ=0.4 |  0.398  | 0.386 |
# | student, λ=0.5 |  0.401  |  0.38 |
# | student, λ=0.6 |  0.409  | 0.365 |
# | student, λ=0.7 |  0.412  | 0.343 |
# | student, λ=0.8 |  0.417  | 0.304 |
# +----------------+---------+-------+
# [[0.908 0.799 0.44  0.351 0.28  0.708 0.86  0.954 0.8   0.604]
#  [0.788 0.828 0.36  0.36  0.26  0.755 0.78  0.948 0.84  0.583]
#  [0.79  0.761 0.46  0.425 0.32  0.726 0.86  0.91  0.86  0.523]
#  [0.799 0.766 0.453 0.38  0.36  0.733 0.78  0.956 0.82  0.629]
#  [0.786 0.774 0.426 0.345 0.38  0.752 0.78  0.926 0.824 0.588]
#  [0.794 0.758 0.468 0.337 0.306 0.755 0.84  0.946 0.84  0.591]
#  [0.795 0.771 0.42  0.342 0.268 0.709 0.82  0.923 0.82  0.608]
#  [0.778 0.769 0.435 0.341 0.308 0.68  0.766 0.929 0.84  0.531]
#  [0.792 0.779 0.444 0.331 0.309 0.703 0.782 0.911 0.82  0.61 ]
#  [0.758 0.77  0.456 0.325 0.295 0.71  0.77  0.914 0.84  0.613]]
# [[ 98. 189.  50.  74.  50.  96.  50. 108.  50. 169.]
#  [397. 122.  50.  50.  50. 102.  50.  96.  50. 151.]
#  [415. 524.  50.  73.  50. 146.  50.  89.  50. 109.]
#  [353. 461. 192.  50.  50. 150.  50.  91.  50. 205.]
#  [370. 496. 183. 391.  50. 113.  50. 176.  51. 187.]
#  [418. 559. 190. 389. 108.  94.  50. 111.  50. 159.]
#  [404. 525. 176. 395. 138. 436.  50. 130.  50. 263.]
#  [397. 520. 223. 369. 146. 475. 167. 127.  50. 145.]
#  [371. 512. 171. 320. 165. 465. 174. 349.  50. 146.]
#  [463. 556. 160. 357. 122. 441. 191. 407. 318. 243.]]
# bagging_renew_models_PU/noise_0.8_clean_data_size_50_additional_data_size_2000/bagging_threshold_0.95_add_criterion_90_minimum_additional_size_50/seed_10/
# +----------------+---------+-------+
# |      line      | Maximum |  Last |
# +----------------+---------+-------+
# |   benchmark    |  0.377  | 0.162 |
# |    teacher     |  0.379  | 0.379 |
# | student, λ=0.3 |  0.394  | 0.388 |
# | student, λ=0.4 |  0.397  | 0.384 |
# | student, λ=0.5 |  0.401  | 0.377 |
# | student, λ=0.6 |  0.407  | 0.363 |
# | student, λ=0.7 |  0.413  | 0.339 |
# | student, λ=0.8 |  0.416  | 0.302 |
# +----------------+---------+-------+

# %%
# dirs2

for threshold in [0.85, 0.95]:
    for criterion in [75, 90]:
        folder = dirs2 + 'bagging_threshold_' + str(threshold) + '_add_criterion_' + str(criterion) + \
                '_minimum_additional_size_50/seed_10/'
        precision_file = open(folder + 'precision_file.txt')
        
        line = precision_file.readlines()
        precision = np.zeros((10, 10))
        number = np.zeros((10, 10))
        for i in range(10):
            precision[:, i] = [float(x) for x in line[i*2].replace('[', '').replace(']', '').replace('\n', '').split(',')]
            number[:, i] = [int(x) for x in line[i*2+1].replace('[', '').replace(']', '').replace('\n', '').split(',')]
            
        print(np.around(precision, decimals=3))
        print(number)
        print(folder)
        lambda_list = [0.3, 0.4, 0.5, 0.6, 0.7, 0.8, 0.9, 1]
        student_accuracy = np.zeros((8, 5, 50))
        teacher_accuracy = np.zeros((5, 50))
        for lambda_i in range(8):
            for index in range(5):
                student_file = open(folder + 'file_student_' + str(index) + '.txt')
                teacher_file = open(folder + 'file_teacher_' + str(index) + '.txt')

                line = student_file.readlines()
                student_accuracy[lambda_i, index, :] = [float(x) for x in line[lambda_i*4+3].replace('[', '').replace(']', '').replace('\n', '').split(',')]
                
                line = teacher_file.readlines()
                accuracy = [float(x) for x in line[3].replace('[', '').replace(']', '').replace('\n', '').split(',')]
                if len(accuracy) < 50:
                    accuracy = accuracy + [accuracy[-1]]*(50-len(accuracy))
                teacher_accuracy[index, :] = accuracy
        student_accuracy = np.mean(student_accuracy, axis=1)
        teacher_accuracy = np.mean(teacher_accuracy, axis=0)
        
        plt.figure(1) # 创建图表1
        plt.figure(figsize=(10,6))
        plt.plot(np.arange(50)+1, benchmark_accuracy, '--', label='benchmark')
        plt.plot(np.arange(50)+1, teacher_accuracy, ':', label='teacher')
        for lambda_i in range(8):
            plt.plot(np.arange(50)+1, student_accuracy[lambda_i], label='student, $\lambda$=%.1f'%lambda_list[lambda_i])
        
        plt.legend()
        plt.grid()
        plt.ylim(0,1)
        plt.xlabel('epoch')
        plt.ylabel('accuracy')
        plt.title('confident threshold %.2f, adding criterion %d'%(threshold, criterion))

        dirs = 'figure/' + dirs1
        if not os.path.exists(dirs):
            os.makedirs(dirs)
        plt.savefig(dirs + 'bagging_threshold_' + str(threshold) + '_add_criterion_' + str(criterion) + '_minimum_additional_size_50.png')
        plt.show()
        
        table = PrettyTable(['line', 'Maximum', 'Last'])
        table.add_row(['benchmark', np.round(np.max(benchmark_accuracy), decimals=3), np.round(benchmark_accuracy[-1], decimals=3)])
        table.add_row(['teacher', np.round(np.max(teacher_accuracy), decimals=3), np.round(teacher_accuracy[-1], decimals=3)])
        for i in range(8):
            table.add_row(['student, λ='+str(lambda_list[i]), np.round(np.max(student_accuracy[i]), decimals=3), np.round(student_accuracy[i, -1], decimals=3)])
        print(table)
# Out:
# [[0.631 0.597 0.397 0.324 0.29  0.537 0.633 0.685 0.636 0.558]
#  [0.629 0.621 0.426 0.32  0.329 0.545 0.577 0.689 0.703 0.57 ]
#  [0.622 0.626 0.445 0.338 0.361 0.563 0.613 0.731 0.73  0.576]
#  [0.62  0.632 0.426 0.353 0.408 0.592 0.638 0.794 0.769 0.605]
#  [0.621 0.634 0.43  0.331 0.436 0.616 0.655 0.81  0.797 0.62 ]
#  [0.624 0.644 0.423 0.324 0.394 0.617 0.674 0.82  0.816 0.65 ]
#  [0.624 0.64  0.425 0.319 0.378 0.585 0.702 0.853 0.824 0.657]
#  [0.625 0.642 0.425 0.317 0.383 0.57  0.611 0.87  0.841 0.666]
#  [0.625 0.643 0.42  0.311 0.382 0.568 0.607 0.781 0.842 0.669]
#  [0.624 0.647 0.418 0.313 0.387 0.566 0.602 0.778 0.796 0.685]]
# [[1743. 2000.  986. 1538.  818. 1762.  610. 1514. 2000. 2000.]
#  [2000. 1762. 1202. 1882. 1079. 1592. 1094. 1525. 2000. 2000.]
#  [2000. 2000.  888. 1387.  570. 1320.  875. 1237. 1794. 1832.]
#  [2000. 2000. 1352. 1029.  409. 1019.  654.  941. 1500. 1388.]
#  [2000. 2000. 1480. 1582.  220.  804.  550.  847. 1208. 1250.]
#  [2000. 2000. 1540. 1709.  766.  702.  509.  789. 1059. 1034.]
#  [2000. 2000. 1557. 1782.  760. 1222.  416.  726. 1009.  863.]
#  [2000. 2000. 1599. 1819.  745. 1340.  954.  645.  872.  809.]
#  [2000. 2000. 1614. 1891.  765. 1330. 1025. 1178.  848.  758.]
#  [2000. 2000. 1630. 1862.  781. 1395. 1061. 1213. 1521.  648.]]
# bagging_without_renew_models_PU/noise_0.8_clean_data_size_50_additional_data_size_2000/bagging_threshold_0.85_add_criterion_75_minimum_additional_size_50/seed_10/
# +----------------+---------+-------+
# |      line      | Maximum |  Last |
# +----------------+---------+-------+
# |   benchmark    |  0.377  | 0.162 |
# |    teacher     |   0.4   | 0.396 |
# | student, λ=0.3 |  0.409  | 0.401 |
# | student, λ=0.4 |  0.411  | 0.399 |
# | student, λ=0.5 |  0.417  | 0.387 |
# | student, λ=0.6 |   0.42  | 0.375 |
# | student, λ=0.7 |  0.426  | 0.354 |
# | student, λ=0.8 |  0.426  | 0.313 |
# | student, λ=0.9 |  0.427  | 0.248 |
# |  student, λ=1  |  0.364  | 0.162 |
# +----------------+---------+-------+
# [[0.74  0.694 0.427 0.372 0.329 0.641 0.807 0.857 0.738 0.598]
#  [0.714 0.725 0.462 0.357 0.448 0.642 0.742 0.791 0.77  0.614]
#  [0.723 0.717 0.489 0.382 0.468 0.649 0.752 0.853 0.818 0.646]
#  [0.727 0.711 0.49  0.379 0.534 0.671 0.797 0.87  0.845 0.654]
#  [0.719 0.714 0.48  0.344 0.56  0.692 0.806 0.884 0.88  0.667]
#  [0.717 0.711 0.484 0.332 0.472 0.704 0.878 0.884 0.873 0.686]
#  [0.713 0.71  0.483 0.338 0.445 0.684 0.866 0.889 0.877 0.715]
#  [0.715 0.719 0.49  0.335 0.475 0.672 0.757 0.893 0.904 0.706]
#  [0.713 0.706 0.491 0.326 0.463 0.668 0.778 0.878 0.902 0.724]
#  [0.715 0.718 0.48  0.333 0.451 0.672 0.779 0.886 0.872 0.742]]
# [[ 726.  765.  211.  409.   70.  744.   83.  574.  770. 1001.]
#  [1131.  789.  333.  695.  174.  704.  322.  818.  890. 1050.]
#  [1140. 1023.  309.  534.  109.  539.  282.  578.  746.  838.]
#  [1108. 1097.  506.  430.   73.  435.  197.  539.  599.  654.]
#  [1132. 1141.  527.  619.   50.  354.  144.  476.  490.  591.]
#  [1150. 1182.  581.  705.  127.  277.  115.  389.  433.  500.]
#  [1153. 1201.  563.  734.  110.  487.  112.  334.  397.  407.]
#  [1153. 1216.  576.  746.   99.  509.  296.  318.  332.  378.]
#  [1143. 1249.  586.  760.   95.  548.  279.  576.  266.  283.]
#  [1147. 1219.  554.  760.   91.  540.  285.  570.  592.  248.]]
# bagging_without_renew_models_PU/noise_0.8_clean_data_size_50_additional_data_size_2000/bagging_threshold_0.85_add_criterion_90_minimum_additional_size_50/seed_10/
# +----------------+---------+-------+
# |      line      | Maximum |  Last |
# +----------------+---------+-------+
# |   benchmark    |  0.377  | 0.162 |
# |    teacher     |  0.389  | 0.386 |
# | student, λ=0.3 |   0.4   | 0.391 |
# | student, λ=0.4 |  0.404  | 0.389 |
# | student, λ=0.5 |  0.407  |  0.38 |
# | student, λ=0.6 |  0.413  | 0.366 |
# | student, λ=0.7 |  0.417  | 0.343 |
# | student, λ=0.8 |  0.424  | 0.308 |
# | student, λ=0.9 |  0.428  | 0.247 |
# |  student, λ=1  |  0.364  | 0.163 |
# +----------------+---------+-------+
# [[0.753 0.716 0.398 0.373 0.38  0.695 0.86  0.861 0.825 0.596]
#  [0.734 0.726 0.439 0.339 0.357 0.64  0.718 0.835 0.769 0.608]
#  [0.731 0.713 0.457 0.347 0.37  0.655 0.751 0.847 0.8   0.621]
#  [0.726 0.699 0.461 0.377 0.365 0.665 0.77  0.862 0.848 0.635]
#  [0.731 0.698 0.46  0.343 0.426 0.666 0.769 0.877 0.845 0.626]
#  [0.722 0.697 0.458 0.344 0.36  0.683 0.783 0.878 0.857 0.645]
#  [0.723 0.695 0.464 0.337 0.348 0.659 0.795 0.884 0.861 0.664]
#  [0.719 0.694 0.461 0.331 0.357 0.653 0.698 0.897 0.854 0.688]
#  [0.724 0.693 0.453 0.329 0.385 0.649 0.708 0.878 0.881 0.691]
#  [0.711 0.687 0.456 0.326 0.363 0.646 0.704 0.876 0.846 0.687]]
# [[ 453.  563.  128.  300.   50.  463.   50.  452.  338.  559.]
#  [ 930.  700.  458.  652.  168.  700.  245.  684.  769. 1035.]
#  [ 972. 1006.  339.  577.  138.  609.  245.  635.  749.  947.]
#  [ 967. 1128.  555.  491.   85.  499.  213.  560.  639.  750.]
#  [ 967. 1227.  630.  760.   68.  449.  182.  488.  582.  689.]
#  [1009. 1282.  674.  787.  172.  353.  152.  476.  547.  535.]
#  [ 982. 1274.  681.  852.  158.  584.  112.  397.  488.  521.]
#  [1005. 1337.  709.  905.  168.  640.  361.  380.  445.  414.]
#  [ 994. 1350.  715.  933.  174.  649.  342.  630.  395.  356.]
#  [1013. 1383.  715.  952.  171.  676.  334.  680.  748.  313.]]
# bagging_without_renew_models_PU/noise_0.8_clean_data_size_50_additional_data_size_2000/bagging_threshold_0.95_add_criterion_75_minimum_additional_size_50/seed_10/
# +----------------+---------+-------+
# |      line      | Maximum |  Last |
# +----------------+---------+-------+
# |   benchmark    |  0.377  | 0.162 |
# |    teacher     |  0.385  | 0.384 |
# | student, λ=0.3 |  0.399  | 0.391 |
# | student, λ=0.4 |  0.401  | 0.389 |
# | student, λ=0.5 |  0.406  | 0.382 |
# | student, λ=0.6 |   0.41  | 0.367 |
# | student, λ=0.7 |  0.416  | 0.342 |
# | student, λ=0.8 |  0.422  | 0.306 |
# | student, λ=0.9 |  0.422  | 0.254 |
# |  student, λ=1  |  0.364  | 0.167 |
# +----------------+---------+-------+
# [[0.873 0.783 0.46  0.388 0.26  0.75  0.82  0.964 0.86  0.635]
#  [0.821 0.824 0.506 0.385 0.42  0.692 0.9   0.906 0.874 0.644]
#  [0.799 0.799 0.524 0.4   0.46  0.703 0.844 0.898 0.891 0.661]
#  [0.81  0.806 0.491 0.394 0.52  0.72  0.923 0.901 0.882 0.669]
#  [0.82  0.802 0.505 0.381 0.54  0.675 0.86  0.884 0.888 0.699]
#  [0.809 0.803 0.495 0.372 0.518 0.737 0.86  0.902 0.897 0.702]
#  [0.795 0.802 0.478 0.372 0.491 0.733 0.9   0.89  0.914 0.729]
#  [0.813 0.807 0.487 0.356 0.459 0.708 0.909 0.911 0.934 0.705]
#  [0.817 0.804 0.47  0.374 0.509 0.713 0.93  0.916 0.94  0.74 ]
#  [0.817 0.804 0.472 0.354 0.491 0.733 0.914 0.921 0.918 0.78 ]]
# [[118. 184.  50.  85.  50. 108.  50. 112.  50. 167.]
#  [352. 278.  77. 231.  50. 273.  50. 287. 238. 419.]
#  [359. 374.  63. 210.  50. 185.  64. 254. 230. 342.]
#  [357. 428. 114. 142.  50. 161.  52. 243. 212. 335.]
#  [334. 455. 109. 247.  50. 126.  50. 242. 197. 266.]
#  [340. 478. 111. 258.  56.  99.  50. 214. 185. 208.]
#  [337. 489. 113. 253.  57. 176.  50. 173. 163. 166.]
#  [305. 502. 113. 270.  61. 171.  77. 180. 121. 146.]
#  [301. 504. 115. 273.  57. 171.  71. 287. 100. 127.]
#  [333. 515. 108. 271.  57. 176.  70. 304. 194.  82.]]
# bagging_without_renew_models_PU/noise_0.8_clean_data_size_50_additional_data_size_2000/bagging_threshold_0.95_add_criterion_90_minimum_additional_size_50/seed_10/
# +----------------+---------+-------+
# |      line      | Maximum |  Last |
# +----------------+---------+-------+
# |   benchmark    |  0.377  | 0.162 |
# |    teacher     |  0.379  | 0.378 |
# | student, λ=0.3 |  0.392  | 0.389 |
# | student, λ=0.4 |  0.394  | 0.381 |
# | student, λ=0.5 |  0.399  | 0.374 |
# | student, λ=0.6 |  0.406  | 0.361 |
# | student, λ=0.7 |  0.412  | 0.341 |
# | student, λ=0.8 |  0.422  | 0.308 |
# | student, λ=0.9 |   0.42  | 0.248 |
# |  student, λ=1  |  0.355  | 0.163 |
# +----------------+---------+-------+

# %%
# dirs3

for threshold in [0.8, 0.85, 0.9, 0.95]:
    for criterion in [75, 90]:
        folder = dirs3 + 'bagging_threshold_' + str(threshold) + '_add_criterion_' + str(criterion) + \
                '_minimum_additional_size_50/seed_10/'
        precision_file = open(folder + 'precision_file.txt')
        
        line = precision_file.readlines()
        precision = np.zeros((10, 10))
        number = np.zeros((10, 10))
        for i in range(10):
            precision[:, i] = [float(x) for x in line[i*2].replace('[', '').replace(']', '').replace('\n', '').split(',')]
            number[:, i] = [int(x) for x in line[i*2+1].replace('[', '').replace(']', '').replace('\n', '').split(',')]
            
#         print(np.around(precision, decimals=3))
#         print(number)
        print(folder)
        lambda_list = [0.3, 0.4, 0.5, 0.6, 0.7, 0.8]
        student_accuracy = np.zeros((6, 5, 50))
        teacher_accuracy = np.zeros((5, 50))
        for lambda_i in range(6):
            for index in range(5):
                student_file = open(folder + 'file_student_' + str(index) + '.txt')
                teacher_file = open(folder + 'file_teacher_' + str(index) + '.txt')

                line = student_file.readlines()
                student_accuracy[lambda_i, index, :] = [float(x) for x in line[lambda_i*4+3].replace('[', '').replace(']', '').replace('\n', '').split(',')]
                
                line = teacher_file.readlines()
                accuracy = [float(x) for x in line[3].replace('[', '').replace(']', '').replace('\n', '').split(',')]
                if len(accuracy) < 50:
                    accuracy = accuracy + [accuracy[-1]]*(50-len(accuracy))
                teacher_accuracy[index, :] = accuracy
        student_accuracy = np.mean(student_accuracy, axis=1)
        teacher_accuracy = np.mean(teacher_accuracy, axis=0)
        
        plt.figure(1) # 创建图表1
        plt.figure(figsize=(10,6))
        plt.plot(np.arange(50)+1, benchmark_accuracy2, '--', label='benchmark')
        plt.plot(np.arange(50)+1, teacher_accuracy, ':', label='teacher')
        for lambda_i in range(6):
            plt.plot(np.arange(50)+1, student_accuracy[lambda_i], label='student, $\lambda$=%.1f'%lambda_list[lambda_i])
        
        plt.legend()
        plt.grid()
        plt.ylim(0,1)
        plt.xlabel('epoch')
        plt.ylabel('accuracy')
        plt.title('confident threshold %.2f, adding criterion %d'%(threshold, criterion))

        dirs = 'figure/' + dirs1
        if not os.path.exists(dirs):
            os.makedirs(dirs)
        plt.savefig(dirs + 'bagging_threshold_' + str(threshold) + '_add_criterion_' + str(criterion) + '_minimum_additional_size_50.png')
#         plt.show()
        
        table = PrettyTable(['line', 'Maximum', 'Last'])
        table.add_row(['benchmark', np.round(np.max(benchmark_accuracy2), decimals=3), np.round(benchmark_accuracy2[-1], decimals=3)])
        table.add_row(['teacher', np.round(np.max(teacher_accuracy), decimals=3), np.round(teacher_accuracy[-1], decimals=3)])
        for i in range(6):
            table.add_row(['student, λ='+str(lambda_list[i]), np.round(np.max(student_accuracy[i]), decimals=3), np.round(student_accuracy[i, -1], decimals=3)])
        print(table)
# Out:
# bagging_renew_models_PU/noise_0.5_clean_data_size_50_additional_data_size_2000/bagging_threshold_0.8_add_criterion_75_minimum_additional_size_50/seed_10/
# +----------------+---------+-------+
# |      line      | Maximum |  Last |
# +----------------+---------+-------+
# |   benchmark    |  0.602  | 0.423 |
# |    teacher     |  0.385  | 0.383 |
# | student, λ=0.3 |  0.425  | 0.422 |
# | student, λ=0.4 |  0.445  |  0.44 |
# | student, λ=0.5 |  0.467  | 0.451 |
# | student, λ=0.6 |  0.496  | 0.466 |
# | student, λ=0.7 |  0.534  | 0.472 |
# | student, λ=0.8 |  0.571  | 0.476 |
# +----------------+---------+-------+
# bagging_renew_models_PU/noise_0.5_clean_data_size_50_additional_data_size_2000/bagging_threshold_0.8_add_criterion_90_minimum_additional_size_50/seed_10/
# +----------------+---------+-------+
# |      line      | Maximum |  Last |
# +----------------+---------+-------+
# |   benchmark    |  0.602  | 0.423 |
# |    teacher     |  0.395  | 0.391 |
# | student, λ=0.3 |  0.434  | 0.432 |
# | student, λ=0.4 |  0.452  | 0.446 |
# | student, λ=0.5 |  0.477  | 0.458 |
# | student, λ=0.6 |  0.502  | 0.467 |
# | student, λ=0.7 |  0.539  | 0.476 |
# | student, λ=0.8 |  0.575  |  0.48 |
# +----------------+---------+-------+
# bagging_renew_models_PU/noise_0.5_clean_data_size_50_additional_data_size_2000/bagging_threshold_0.85_add_criterion_75_minimum_additional_size_50/seed_10/
# +----------------+---------+-------+
# |      line      | Maximum |  Last |
# +----------------+---------+-------+
# |   benchmark    |  0.602  | 0.423 |
# |    teacher     |  0.386  | 0.385 |
# | student, λ=0.3 |  0.428  | 0.427 |
# | student, λ=0.4 |  0.446  | 0.441 |
# | student, λ=0.5 |   0.47  | 0.451 |
# | student, λ=0.6 |  0.497  | 0.462 |
# | student, λ=0.7 |  0.532  | 0.476 |
# | student, λ=0.8 |  0.569  | 0.475 |
# +----------------+---------+-------+
# bagging_renew_models_PU/noise_0.5_clean_data_size_50_additional_data_size_2000/bagging_threshold_0.85_add_criterion_90_minimum_additional_size_50/seed_10/
# +----------------+---------+-------+
# |      line      | Maximum |  Last |
# +----------------+---------+-------+
# |   benchmark    |  0.602  | 0.423 |
# |    teacher     |   0.39  | 0.389 |
# | student, λ=0.3 |  0.434  | 0.429 |
# | student, λ=0.4 |  0.452  | 0.444 |
# | student, λ=0.5 |  0.474  | 0.455 |
# | student, λ=0.6 |  0.502  | 0.466 |
# | student, λ=0.7 |  0.538  | 0.475 |
# | student, λ=0.8 |  0.569  | 0.476 |
# +----------------+---------+-------+
# bagging_renew_models_PU/noise_0.5_clean_data_size_50_additional_data_size_2000/bagging_threshold_0.9_add_criterion_75_minimum_additional_size_50/seed_10/
# +----------------+---------+-------+
# |      line      | Maximum |  Last |
# +----------------+---------+-------+
# |   benchmark    |  0.602  | 0.423 |
# |    teacher     |  0.393  | 0.386 |
# | student, λ=0.3 |  0.429  | 0.424 |
# | student, λ=0.4 |  0.444  | 0.438 |
# | student, λ=0.5 |  0.469  | 0.448 |
# | student, λ=0.6 |  0.496  | 0.464 |
# | student, λ=0.7 |  0.534  | 0.474 |
# | student, λ=0.8 |  0.572  | 0.483 |
# +----------------+---------+-------+
# bagging_renew_models_PU/noise_0.5_clean_data_size_50_additional_data_size_2000/bagging_threshold_0.9_add_criterion_90_minimum_additional_size_50/seed_10/
# +----------------+---------+-------+
# |      line      | Maximum |  Last |
# +----------------+---------+-------+
# |   benchmark    |  0.602  | 0.423 |
# |    teacher     |  0.385  | 0.385 |
# | student, λ=0.3 |   0.43  | 0.427 |
# | student, λ=0.4 |  0.447  |  0.44 |
# | student, λ=0.5 |  0.472  | 0.455 |
# | student, λ=0.6 |  0.501  | 0.465 |
# | student, λ=0.7 |   0.54  | 0.475 |
# | student, λ=0.8 |  0.577  | 0.479 |
# +----------------+---------+-------+
# bagging_renew_models_PU/noise_0.5_clean_data_size_50_additional_data_size_2000/bagging_threshold_0.95_add_criterion_75_minimum_additional_size_50/seed_10/
# +----------------+---------+-------+
# |      line      | Maximum |  Last |
# +----------------+---------+-------+
# |   benchmark    |  0.602  | 0.423 |
# |    teacher     |  0.388  | 0.388 |
# | student, λ=0.3 |  0.432  | 0.428 |
# | student, λ=0.4 |  0.451  | 0.443 |
# | student, λ=0.5 |  0.476  | 0.456 |
# | student, λ=0.6 |  0.503  | 0.469 |
# | student, λ=0.7 |  0.537  | 0.475 |
# | student, λ=0.8 |  0.577  |  0.48 |
# +----------------+---------+-------+
# bagging_renew_models_PU/noise_0.5_clean_data_size_50_additional_data_size_2000/bagging_threshold_0.95_add_criterion_90_minimum_additional_size_50/seed_10/
# +----------------+---------+-------+
# |      line      | Maximum |  Last |
# +----------------+---------+-------+
# |   benchmark    |  0.602  | 0.423 |
# |    teacher     |  0.384  |  0.38 |
# | student, λ=0.3 |  0.429  | 0.426 |
# | student, λ=0.4 |  0.447  | 0.439 |
# | student, λ=0.5 |  0.471  | 0.451 |
# | student, λ=0.6 |  0.503  | 0.464 |
# | student, λ=0.7 |   0.54  | 0.474 |
# | student, λ=0.8 |  0.571  | 0.476 |
# +----------------+---------+-------+

# %%
# dirs4

for threshold in [0.8, 0.85, 0.9, 0.95]:
    for criterion in [75, 90]:
        folder = dirs4 + 'bagging_threshold_' + str(threshold) + '_add_criterion_' + str(criterion) + \
                '_minimum_additional_size_50/seed_10/'
        precision_file = open(folder + 'precision_file.txt')
        
        line = precision_file.readlines()
        precision = np.zeros((10, 10))
        number = np.zeros((10, 10))
        for i in range(10):
            precision[:, i] = [float(x) for x in line[i*2].replace('[', '').replace(']', '').replace('\n', '').split(',')]
            number[:, i] = [int(x) for x in line[i*2+1].replace('[', '').replace(']', '').replace('\n', '').split(',')]
            
#         print(np.around(precision, decimals=3))
#         print(number)
        print(folder)
        lambda_list = [0.3, 0.4, 0.5, 0.6, 0.7, 0.8]
        student_accuracy = np.zeros((6, 5, 50))
        teacher_accuracy = np.zeros((5, 50))
        for lambda_i in range(6):
            for index in range(5):
                student_file = open(folder + 'file_student_' + str(index) + '.txt')
                teacher_file = open(folder + 'file_teacher_' + str(index) + '.txt')

                line = student_file.readlines()
                student_accuracy[lambda_i, index, :] = [float(x) for x in line[lambda_i*4+3].replace('[', '').replace(']', '').replace('\n', '').split(',')]
                
                line = teacher_file.readlines()
                accuracy = [float(x) for x in line[3].replace('[', '').replace(']', '').replace('\n', '').split(',')]
                if len(accuracy) < 50:
                    accuracy = accuracy + [accuracy[-1]]*(50-len(accuracy))
                teacher_accuracy[index, :] = accuracy
        student_accuracy = np.mean(student_accuracy, axis=1)
        teacher_accuracy = np.mean(teacher_accuracy, axis=0)
        
        plt.figure(1) # 创建图表1
        plt.figure(figsize=(10,6))
        plt.plot(np.arange(50)+1, benchmark_accuracy2, '--', label='benchmark')
        plt.plot(np.arange(50)+1, teacher_accuracy, ':', label='teacher')
        for lambda_i in range(6):
            plt.plot(np.arange(50)+1, student_accuracy[lambda_i], label='student, $\lambda$=%.1f'%lambda_list[lambda_i])
        
        plt.legend()
        plt.grid()
        plt.ylim(0,1)
        plt.xlabel('epoch')
        plt.ylabel('accuracy')
        plt.title('confident threshold %.2f, adding criterion %d'%(threshold, criterion))

        dirs = 'figure/' + dirs1
        if not os.path.exists(dirs):
            os.makedirs(dirs)
        plt.savefig(dirs + 'bagging_threshold_' + str(threshold) + '_add_criterion_' + str(criterion) + '_minimum_additional_size_50.png')
#         plt.show()
        
        table = PrettyTable(['line', 'Maximum', 'Last'])
        table.add_row(['benchmark', np.round(np.max(benchmark_accuracy2), decimals=3), np.round(benchmark_accuracy2[-1], decimals=3)])
        table.add_row(['teacher', np.round(np.max(teacher_accuracy), decimals=3), np.round(teacher_accuracy[-1], decimals=3)])
        for i in range(6):
            table.add_row(['student, λ='+str(lambda_list[i]), np.round(np.max(student_accuracy[i]), decimals=3), np.round(student_accuracy[i, -1], decimals=3)])
        print(table)
# Out:
# bagging_without_renew_models_PU/noise_0.5_clean_data_size_50_additional_data_size_2000/bagging_threshold_0.8_add_criterion_75_minimum_additional_size_50/seed_10/
# +----------------+---------+-------+
# |      line      | Maximum |  Last |
# +----------------+---------+-------+
# |   benchmark    |  0.602  | 0.423 |
# |    teacher     |  0.401  | 0.399 |
# | student, λ=0.3 |  0.445  | 0.444 |
# | student, λ=0.4 |  0.462  | 0.454 |
# | student, λ=0.5 |  0.485  | 0.462 |
# | student, λ=0.6 |  0.512  | 0.475 |
# | student, λ=0.7 |  0.546  | 0.483 |
# | student, λ=0.8 |  0.577  |  0.48 |
# +----------------+---------+-------+
# bagging_without_renew_models_PU/noise_0.5_clean_data_size_50_additional_data_size_2000/bagging_threshold_0.8_add_criterion_90_minimum_additional_size_50/seed_10/
# +----------------+---------+-------+
# |      line      | Maximum |  Last |
# +----------------+---------+-------+
# |   benchmark    |  0.602  | 0.423 |
# |    teacher     |   0.39  | 0.389 |
# | student, λ=0.3 |  0.434  | 0.429 |
# | student, λ=0.4 |  0.452  | 0.442 |
# | student, λ=0.5 |  0.476  | 0.458 |
# | student, λ=0.6 |  0.507  | 0.465 |
# | student, λ=0.7 |  0.539  | 0.477 |
# | student, λ=0.8 |  0.571  |  0.48 |
# +----------------+---------+-------+
# bagging_without_renew_models_PU/noise_0.5_clean_data_size_50_additional_data_size_2000/bagging_threshold_0.85_add_criterion_75_minimum_additional_size_50/seed_10/
# +----------------+---------+-------+
# |      line      | Maximum |  Last |
# +----------------+---------+-------+
# |   benchmark    |  0.602  | 0.423 |
# |    teacher     |  0.397  | 0.396 |
# | student, λ=0.3 |  0.443  | 0.439 |
# | student, λ=0.4 |  0.462  | 0.453 |
# | student, λ=0.5 |  0.483  | 0.465 |
# | student, λ=0.6 |  0.513  | 0.472 |
# | student, λ=0.7 |  0.546  | 0.485 |
# | student, λ=0.8 |  0.575  | 0.477 |
# +----------------+---------+-------+
# bagging_without_renew_models_PU/noise_0.5_clean_data_size_50_additional_data_size_2000/bagging_threshold_0.85_add_criterion_90_minimum_additional_size_50/seed_10/
# +----------------+---------+-------+
# |      line      | Maximum |  Last |
# +----------------+---------+-------+
# |   benchmark    |  0.602  | 0.423 |
# |    teacher     |  0.386  | 0.382 |
# | student, λ=0.3 |  0.428  | 0.424 |
# | student, λ=0.4 |  0.447  | 0.436 |
# | student, λ=0.5 |  0.472  | 0.452 |
# | student, λ=0.6 |  0.501  | 0.465 |
# | student, λ=0.7 |  0.537  | 0.474 |
# | student, λ=0.8 |  0.572  | 0.473 |
# +----------------+---------+-------+
# bagging_without_renew_models_PU/noise_0.5_clean_data_size_50_additional_data_size_2000/bagging_threshold_0.9_add_criterion_75_minimum_additional_size_50/seed_10/
# +----------------+---------+-------+
# |      line      | Maximum |  Last |
# +----------------+---------+-------+
# |   benchmark    |  0.602  | 0.423 |
# |    teacher     |  0.391  | 0.389 |
# | student, λ=0.3 |  0.437  | 0.433 |
# | student, λ=0.4 |  0.454  | 0.447 |
# | student, λ=0.5 |  0.477  | 0.457 |
# | student, λ=0.6 |  0.507  | 0.463 |
# | student, λ=0.7 |   0.54  | 0.475 |
# | student, λ=0.8 |  0.573  | 0.478 |
# +----------------+---------+-------+
# bagging_without_renew_models_PU/noise_0.5_clean_data_size_50_additional_data_size_2000/bagging_threshold_0.9_add_criterion_90_minimum_additional_size_50/seed_10/
# +----------------+---------+-------+
# |      line      | Maximum |  Last |
# +----------------+---------+-------+
# |   benchmark    |  0.602  | 0.423 |
# |    teacher     |  0.384  |  0.38 |
# | student, λ=0.3 |  0.429  | 0.423 |
# | student, λ=0.4 |  0.448  | 0.437 |
# | student, λ=0.5 |  0.473  |  0.45 |
# | student, λ=0.6 |  0.504  | 0.463 |
# | student, λ=0.7 |  0.537  | 0.472 |
# | student, λ=0.8 |  0.573  | 0.474 |
# +----------------+---------+-------+
# bagging_without_renew_models_PU/noise_0.5_clean_data_size_50_additional_data_size_2000/bagging_threshold_0.95_add_criterion_75_minimum_additional_size_50/seed_10/
# +----------------+---------+-------+
# |      line      | Maximum |  Last |
# +----------------+---------+-------+
# |   benchmark    |  0.602  | 0.423 |
# |    teacher     |  0.389  | 0.386 |
# | student, λ=0.3 |  0.436  |  0.43 |
# | student, λ=0.4 |  0.453  | 0.444 |
# | student, λ=0.5 |  0.478  | 0.457 |
# | student, λ=0.6 |  0.507  | 0.468 |
# | student, λ=0.7 |   0.54  | 0.474 |
# | student, λ=0.8 |  0.573  | 0.476 |
# +----------------+---------+-------+
# bagging_without_renew_models_PU/noise_0.5_clean_data_size_50_additional_data_size_2000/bagging_threshold_0.95_add_criterion_90_minimum_additional_size_50/seed_10/
# +----------------+---------+-------+
# |      line      | Maximum |  Last |
# +----------------+---------+-------+
# |   benchmark    |  0.602  | 0.423 |
# |    teacher     |  0.376  | 0.369 |
# | student, λ=0.3 |  0.419  | 0.416 |
# | student, λ=0.4 |   0.44  |  0.43 |
# | student, λ=0.5 |  0.465  | 0.443 |
# | student, λ=0.6 |  0.498  | 0.459 |
# | student, λ=0.7 |  0.532  | 0.468 |
# | student, λ=0.8 |  0.569  | 0.467 |
# +----------------+---------+-------+

# %%
# compare teacher model with & without bagging
# dirs1

for threshold in [0.8, 0.85, 0.9, 0.95]:
    for criterion in [75, 90]:
        folder = dirs1 + 'bagging_threshold_' + str(threshold) + '_add_criterion_' + str(criterion) + \
                '_minimum_additional_size_50/seed_10/'
        
        print(folder)
        lambda_list = [0.3, 0.4, 0.5, 0.6, 0.7, 0.8]
        student_accuracy = np.zeros((6, 5, 50))
        student_accuracy_with_bagging_teacher = np.zeros((6, 5, 50))
        teacher_accuracy = np.zeros((5, 50))
        for lambda_i in range(6):
            for index in range(5):
                student_file = open(folder + 'file_student_' + str(index) + '.txt')
                student_file_with_bagging_teacher = open(folder + 'bagging_teacher_file_student_' + str(index) + '.txt')
                teacher_file = open(folder + 'file_teacher_' + str(index) + '.txt')

                line = student_file.readlines()
                student_accuracy[lambda_i, index, :] = [float(x) for x in line[lambda_i*4+3].replace('[', '').replace(']', '').replace('\n', '').split(',')]
                
                line = student_file_with_bagging_teacher.readlines()
                student_accuracy_with_bagging_teacher[lambda_i, index, :] = [float(x) for x in line[lambda_i*4+3].replace('[', '').replace(']', '').replace('\n', '').split(',')]
                
                line = teacher_file.readlines()
                accuracy = [float(x) for x in line[3].replace('[', '').replace(']', '').replace('\n', '').split(',')]
                if len(accuracy) < 50:
                    accuracy = accuracy + [accuracy[-1]]*(50-len(accuracy))
                teacher_accuracy[index, :] = accuracy
        student_accuracy = np.mean(student_accuracy, axis=1)
        student_accuracy_with_bagging_teacher = np.mean(student_accuracy_with_bagging_teacher, axis=1)
        teacher_accuracy = np.mean(teacher_accuracy, axis=0)
        
        table = PrettyTable(['line', 'Maximum', 'Last', 'Maximum (with bagging)', 'Last (with bagging)'])
        table.add_row(['benchmark', np.round(np.max(benchmark_accuracy), decimals=3), np.round(benchmark_accuracy[-1], decimals=3), '/', '/'])
        table.add_row(['teacher', np.round(np.max(teacher_accuracy), decimals=3), np.round(teacher_accuracy[-1], decimals=3), '/', '/'])
        for i in range(6):
            table.add_row(['student, λ='+str(lambda_list[i]), np.round(np.max(student_accuracy[i]), decimals=3), np.round(student_accuracy[i, -1], decimals=3), \
                           np.round(np.max(student_accuracy_with_bagging_teacher[i]), decimals=3), np.round(student_accuracy_with_bagging_teacher[i, -1], decimals=3)])
        print(table)
# Out:
# bagging_renew_models_PU/noise_0.8_clean_data_size_50_additional_data_size_2000/bagging_threshold_0.8_add_criterion_75_minimum_additional_size_50/seed_10/
# +----------------+---------+-------+------------------------+---------------------+
# |      line      | Maximum |  Last | Maximum (with bagging) | Last (with bagging) |
# +----------------+---------+-------+------------------------+---------------------+
# |   benchmark    |  0.377  | 0.162 |           /            |          /          |
# |    teacher     |  0.385  | 0.381 |           /            |          /          |
# | student, λ=0.3 |  0.393  | 0.388 |         0.398          |        0.393        |
# | student, λ=0.4 |  0.396  | 0.387 |          0.4           |        0.388        |
# | student, λ=0.5 |  0.402  | 0.382 |         0.403          |        0.383        |
# | student, λ=0.6 |  0.406  | 0.365 |         0.407          |        0.371        |
# | student, λ=0.7 |   0.41  | 0.346 |         0.412          |        0.348        |
# | student, λ=0.8 |  0.414  | 0.305 |          0.42          |         0.31        |
# +----------------+---------+-------+------------------------+---------------------+
# bagging_renew_models_PU/noise_0.8_clean_data_size_50_additional_data_size_2000/bagging_threshold_0.8_add_criterion_90_minimum_additional_size_50/seed_10/
# +----------------+---------+-------+------------------------+---------------------+
# |      line      | Maximum |  Last | Maximum (with bagging) | Last (with bagging) |
# +----------------+---------+-------+------------------------+---------------------+
# |   benchmark    |  0.377  | 0.162 |           /            |          /          |
# |    teacher     |  0.389  | 0.389 |           /            |          /          |
# | student, λ=0.3 |  0.398  | 0.394 |         0.404          |        0.398        |
# | student, λ=0.4 |  0.402  | 0.391 |         0.404          |        0.395        |
# | student, λ=0.5 |  0.406  | 0.386 |         0.409          |        0.388        |
# | student, λ=0.6 |  0.409  | 0.372 |         0.412          |        0.376        |
# | student, λ=0.7 |  0.415  | 0.352 |         0.416          |        0.349        |
# | student, λ=0.8 |  0.423  | 0.312 |         0.419          |        0.309        |
# +----------------+---------+-------+------------------------+---------------------+
# bagging_renew_models_PU/noise_0.8_clean_data_size_50_additional_data_size_2000/bagging_threshold_0.85_add_criterion_75_minimum_additional_size_50/seed_10/
# +----------------+---------+-------+------------------------+---------------------+
# |      line      | Maximum |  Last | Maximum (with bagging) | Last (with bagging) |
# +----------------+---------+-------+------------------------+---------------------+
# |   benchmark    |  0.377  | 0.162 |           /            |          /          |
# |    teacher     |  0.387  | 0.385 |           /            |          /          |
# | student, λ=0.3 |  0.395  | 0.393 |         0.398          |        0.393        |
# | student, λ=0.4 |  0.398  | 0.388 |         0.401          |        0.391        |
# | student, λ=0.5 |  0.403  | 0.384 |         0.405          |        0.385        |
# | student, λ=0.6 |  0.407  |  0.37 |         0.408          |        0.372        |
# | student, λ=0.7 |   0.41  | 0.347 |         0.413          |        0.351        |
# | student, λ=0.8 |  0.415  | 0.309 |         0.418          |        0.309        |
# +----------------+---------+-------+------------------------+---------------------+
# bagging_renew_models_PU/noise_0.8_clean_data_size_50_additional_data_size_2000/bagging_threshold_0.85_add_criterion_90_minimum_additional_size_50/seed_10/
# +----------------+---------+-------+------------------------+---------------------+
# |      line      | Maximum |  Last | Maximum (with bagging) | Last (with bagging) |
# +----------------+---------+-------+------------------------+---------------------+
# |   benchmark    |  0.377  | 0.162 |           /            |          /          |
# |    teacher     |  0.394  | 0.392 |           /            |          /          |
# | student, λ=0.3 |  0.404  | 0.399 |         0.407          |        0.403        |
# | student, λ=0.4 |  0.409  | 0.395 |          0.41          |        0.397        |
# | student, λ=0.5 |   0.41  | 0.388 |         0.413          |        0.392        |
# | student, λ=0.6 |  0.413  | 0.374 |         0.415          |        0.372        |
# | student, λ=0.7 |  0.421  |  0.35 |          0.42          |        0.354        |
# | student, λ=0.8 |  0.424  | 0.312 |         0.422          |        0.311        |
# +----------------+---------+-------+------------------------+---------------------+
# bagging_renew_models_PU/noise_0.8_clean_data_size_50_additional_data_size_2000/bagging_threshold_0.9_add_criterion_75_minimum_additional_size_50/seed_10/
# +----------------+---------+-------+------------------------+---------------------+
# |      line      | Maximum |  Last | Maximum (with bagging) | Last (with bagging) |
# +----------------+---------+-------+------------------------+---------------------+
# |   benchmark    |  0.377  | 0.162 |           /            |          /          |
# |    teacher     |  0.391  | 0.386 |           /            |          /          |
# | student, λ=0.3 |   0.4   | 0.395 |         0.405          |         0.4         |
# | student, λ=0.4 |  0.401  |  0.39 |         0.406          |        0.397        |
# | student, λ=0.5 |  0.406  | 0.383 |         0.409          |        0.387        |
# | student, λ=0.6 |  0.409  | 0.367 |         0.415          |        0.373        |
# | student, λ=0.7 |  0.414  | 0.347 |         0.418          |        0.347        |
# | student, λ=0.8 |  0.414  | 0.311 |         0.423          |        0.307        |
# +----------------+---------+-------+------------------------+---------------------+
# bagging_renew_models_PU/noise_0.8_clean_data_size_50_additional_data_size_2000/bagging_threshold_0.9_add_criterion_90_minimum_additional_size_50/seed_10/
# +----------------+---------+-------+------------------------+---------------------+
# |      line      | Maximum |  Last | Maximum (with bagging) | Last (with bagging) |
# +----------------+---------+-------+------------------------+---------------------+
# |   benchmark    |  0.377  | 0.162 |           /            |          /          |
# |    teacher     |  0.391  | 0.386 |           /            |          /          |
# | student, λ=0.3 |   0.4   | 0.394 |         0.403          |         0.4         |
# | student, λ=0.4 |  0.404  |  0.39 |         0.406          |        0.395        |
# | student, λ=0.5 |  0.408  | 0.385 |         0.407          |        0.387        |
# | student, λ=0.6 |  0.412  |  0.37 |         0.413          |         0.37        |
# | student, λ=0.7 |  0.418  | 0.345 |         0.419          |        0.346        |
# | student, λ=0.8 |  0.418  | 0.304 |         0.422          |        0.309        |
# +----------------+---------+-------+------------------------+---------------------+
# bagging_renew_models_PU/noise_0.8_clean_data_size_50_additional_data_size_2000/bagging_threshold_0.95_add_criterion_75_minimum_additional_size_50/seed_10/
# +----------------+---------+-------+------------------------+---------------------+
# |      line      | Maximum |  Last | Maximum (with bagging) | Last (with bagging) |
# +----------------+---------+-------+------------------------+---------------------+
# |   benchmark    |  0.377  | 0.162 |           /            |          /          |
# |    teacher     |  0.383  | 0.383 |           /            |          /          |
# | student, λ=0.3 |  0.395  |  0.39 |         0.397          |        0.393        |
# | student, λ=0.4 |  0.398  | 0.386 |         0.401          |        0.388        |
# | student, λ=0.5 |  0.401  |  0.38 |         0.405          |        0.383        |
# | student, λ=0.6 |  0.409  | 0.365 |         0.407          |        0.366        |
# | student, λ=0.7 |  0.412  | 0.343 |         0.413          |        0.342        |
# | student, λ=0.8 |  0.417  | 0.304 |         0.419          |        0.305        |
# +----------------+---------+-------+------------------------+---------------------+
# bagging_renew_models_PU/noise_0.8_clean_data_size_50_additional_data_size_2000/bagging_threshold_0.95_add_criterion_90_minimum_additional_size_50/seed_10/
# +----------------+---------+-------+------------------------+---------------------+
# |      line      | Maximum |  Last | Maximum (with bagging) | Last (with bagging) |
# +----------------+---------+-------+------------------------+---------------------+
# |   benchmark    |  0.377  | 0.162 |           /            |          /          |
# |    teacher     |  0.379  | 0.379 |           /            |          /          |
# | student, λ=0.3 |  0.394  | 0.388 |         0.399          |        0.393        |
# | student, λ=0.4 |  0.397  | 0.384 |          0.4           |         0.39        |
# | student, λ=0.5 |  0.401  | 0.377 |         0.406          |         0.38        |
# | student, λ=0.6 |  0.407  | 0.363 |          0.41          |        0.366        |
# | student, λ=0.7 |  0.413  | 0.339 |         0.414          |        0.339        |
# | student, λ=0.8 |  0.416  | 0.302 |         0.422          |        0.299        |
# +----------------+---------+-------+------------------------+---------------------+

# %%
# compare teacher model with & without bagging
# dirs3

for threshold in [0.8, 0.85, 0.9, 0.95]:
    for criterion in [75, 90]:
        folder = dirs3 + 'bagging_threshold_' + str(threshold) + '_add_criterion_' + str(criterion) + \
                '_minimum_additional_size_50/seed_10/'
        
        print(folder)
        lambda_list = [0.3, 0.4, 0.5, 0.6, 0.7, 0.8]
        student_accuracy = np.zeros((6, 4, 50))
        student_accuracy_with_bagging_teacher = np.zeros((6, 4, 50))
        teacher_accuracy = np.zeros((4, 50))
        for lambda_i in range(6):
            for index in range(4):
                student_file = open(folder + 'file_student_' + str(index) + '.txt')
                student_file_with_bagging_teacher = open(folder + 'bagging_teacher_file_student_' + str(index) + '.txt')
                teacher_file = open(folder + 'file_teacher_' + str(index) + '.txt')

                line = student_file.readlines()
                student_accuracy[lambda_i, index, :] = [float(x) for x in line[lambda_i*4+3].replace('[', '').replace(']', '').replace('\n', '').split(',')]
                
                line = student_file_with_bagging_teacher.readlines()
                student_accuracy_with_bagging_teacher[lambda_i, index, :] = [float(x) for x in line[lambda_i*4+3].replace('[', '').replace(']', '').replace('\n', '').split(',')]
                
                line = teacher_file.readlines()
                accuracy = [float(x) for x in line[3].replace('[', '').replace(']', '').replace('\n', '').split(',')]
                if len(accuracy) < 50:
                    accuracy = accuracy + [accuracy[-1]]*(50-len(accuracy))
                teacher_accuracy[index, :] = accuracy
        student_accuracy = np.mean(student_accuracy, axis=1)
        student_accuracy_with_bagging_teacher = np.mean(student_accuracy_with_bagging_teacher, axis=1)
        teacher_accuracy = np.mean(teacher_accuracy, axis=0)
        
        table = PrettyTable(['line', 'Maximum', 'Last', 'Maximum (with bagging)', 'Last (with bagging)'])
        table.add_row(['benchmark', np.round(np.max(benchmark_accuracy), decimals=3), np.round(benchmark_accuracy[-1], decimals=3), '/', '/'])
        table.add_row(['teacher', np.round(np.max(teacher_accuracy), decimals=3), np.round(teacher_accuracy[-1], decimals=3), '/', '/'])
        for i in range(6):
            table.add_row(['student, λ='+str(lambda_list[i]), np.round(np.max(student_accuracy[i]), decimals=3), np.round(student_accuracy[i, -1], decimals=3), \
                           np.round(np.max(student_accuracy_with_bagging_teacher[i]), decimals=3), np.round(student_accuracy_with_bagging_teacher[i, -1], decimals=3)])
        print(table)
# Out:
# bagging_renew_models_PU/noise_0.5_clean_data_size_50_additional_data_size_2000/bagging_threshold_0.8_add_criterion_75_minimum_additional_size_50/seed_10/
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-24-3dd336c6ec83> in <module>
#      15             for index in range(4):
#      16                 student_file = open(folder + 'file_student_' + str(index) + '.txt')
# ---> 17                 student_file_with_bagging_teacher = open(folder + 'bagging_teacher_file_student_' + str(index) + '.txt')
#      18                 teacher_file = open(folder + 'file_teacher_' + str(index) + '.txt')
#      19
#
# FileNotFoundError: [Errno 2] No such file or directory: 'bagging_renew_models_PU/noise_0.5_clean_data_size_50_additional_data_size_2000/bagging_threshold_0.8_add_criterion_75_minimum_additional_size_50/seed_10/bagging_teacher_file_student_2.txt'
