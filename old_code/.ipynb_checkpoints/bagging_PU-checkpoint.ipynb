# %%
# coding: utf-8
import tensorflow as tf
import os
import numpy as np
from copy import deepcopy
import sys

from keras.models import Sequential
from keras.layers import Dense, Activation, Conv2D, MaxPooling2D, Flatten, Dropout
from keras.optimizers import Adam
from keras import backend as K
from keras.callbacks import EarlyStopping

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "5"
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)
K.set_session(sess)

file_index = 1
noise_level = 0.5
clean_data_size = 50
seed = 10 * file_index
additional_data_size = 2000
learning_rate = 0.0003
iteration_num = 20

np.random.seed(seed)
tf.set_random_seed(seed)

x_train, y_train, x_test, y_test, x_clean, y_clean = load_data(clean_data_size)
y_train_orig = deepcopy(y_train)
y_train = generate_noise_labels(y_train, noise_level)

# %%
# load data from CIFAR10
def load_data(clean_data_size):
    cifar10 = tf.keras.datasets.cifar10
    (x_train, y_train), (x_test, y_test) = cifar10.load_data()
    x_train, x_test = x_train / 255.0, x_test / 255.0
    x_train = x_train.reshape(x_train.shape[0], 32, 32, 3)
    x_test = x_test.reshape(x_test.shape[0], 32, 32, 3)

    # transform labels to one-hot vectors
    y_train = tf.contrib.keras.utils.to_categorical(y_train, 10)
    y_test = tf.contrib.keras.utils.to_categorical(y_test, 10)

    clean_index = []
    for label in range(10):
        positive_index = list(np.where(y_train[:, label] == 1)[0])
        clean_index = np.append(clean_index, np.random.choice(positive_index, clean_data_size, replace=False)).astype(
            int)

    x_clean = x_train[clean_index]
    y_clean = y_train[clean_index]
    x_train = np.delete(x_train, clean_index, axis=0)
    y_train = np.delete(y_train, clean_index, axis=0)
    return x_train, y_train, x_test, y_test, x_clean, y_clean


def generate_noise_labels(y_train, noise_level):
    num_noise = int(noise_level * y_train.shape[0])
    noise_index = np.random.choice(y_train.shape[0], num_noise, replace=False)
    label_slice = np.argmax(y_train[noise_index], axis=1)
    new_label = np.random.randint(low=0, high=10, size=num_noise)
    while sum(label_slice == new_label) > 0:
        n = sum(label_slice == new_label)
        new_label[label_slice == new_label] = np.random.randint(low=0, high=10, size=n)
    y_train[noise_index] = tf.contrib.keras.utils.to_categorical(new_label, 10)
    return y_train


def create_model(architecture, num_classes, learning_rate, dropout=0.5):
    model = Sequential()
    for layer_index in range(len(architecture)):
        layer = architecture[layer_index]
        if len(layer) == 3:
            if layer_index == 0:
                model.add(Conv2D(layer[0], kernel_size=(layer[1], layer[2]), input_shape=(32, 32, 3),
                                 kernel_initializer='glorot_normal', activation='relu', padding='same'))
            else:
                model.add(Conv2D(layer[0], kernel_size=(layer[1], layer[2]), kernel_initializer='glorot_normal',
                                 activation='relu', padding='same'))
            if layer_index < 3:
                model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
        elif len(layer) == 1:
            if len(architecture[layer_index - 1]) == 3:
                model.add(Flatten())
            model.add(Dense(layer[0], activation='relu', kernel_initializer='glorot_normal'))
        else:
            print('Invalid architecture /(ㄒoㄒ)/~~')
    model.add(Dropout(dropout))
    if num_classes > 2:
        model.add(Dense(num_classes))
        model.add(Activation('softmax'))
        adam = Adam(lr=learning_rate)
        model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer=adam)
    elif num_classes == 2:
        model.add(Dense(1))
        model.add(Activation('sigmoid'))
        adam = Adam(lr=learning_rate)
        model.compile(loss='mean_squared_error', metrics=['accuracy'], optimizer=adam)
    return model

# %%
def select_additional_data(x, binary_classifier_list, additional_data_size):    
    n = len(binary_classifier_list)
    y = np.zeros((len(x), n))
    
    for index in range(n):
        model = binary_classifier_list[index]
        y_pred = model.predict(x).reshape(-1,)
        y[:, index] = y_pred>0.5 
    
    y = np.sum(y, axis=1)
    
    add_index = np.where(y > 90)[0]
    if len(add_index) > additional_data_size:
        add_index = np.argsort(-y, axis=0)[0:additional_data_size].reshape(-1)
    return add_index

# %%
architecture = [[32, 5, 5], [32, 5, 5], [32, 5, 5], [256]]
additional_data_index = [[] for i in range(10)]

for iteration in range(iteration_num):
    for label in range(10):
        binary_classifier_list = []
        
        # train 100 binary classifiers for one label
        for index in range(100):
            print('iteration', iteration, 'label', label, 'index', index)
            model = create_model(architecture, num_classes=2, learning_rate=learning_rate)
            positive_index = list(np.where(y_clean[:, label] == 1)[0])
            x = x_clean[positive_index]
            
            if len(additional_data_index[label]) < 950:                
                add_positive_index = additional_data_index[label]
            else:
                add_positive_index = np.random.choice(additional_data_index[label], 950, replace=False)
            x = np.concatenate((x, x_train[add_positive_index]), axis=0)
                    
            n_p = len(x)
            n_n_clean = min(450, n_p//2)
            n_n_noisy = n_p - n_n_clean
            negative_index_clean = list(np.where(y_clean[:, label] != 1)[0])
            negative_index_clean = np.random.choice(negative_index_clean, n_n_clean, replace=False)
            x = np.concatenate((x, x_clean[negative_index_clean]), axis=0)
            negative_index_noisy = set(np.arange(len(x_train))) - set(additional_data_index[label])
            negative_index_noisy = np.random.choice(list(negative_index_noisy), n_n_noisy, replace=False)
            x = np.concatenate((x, x_train[negative_index_noisy]), axis=0)
            
            y = [1] * n_p + [0] * n_p
            early_stopping = EarlyStopping(monitor='loss', patience=5)
            model.fit(x, y, batch_size=32, epochs=50, shuffle=True, callbacks=[early_stopping])
            binary_classifier_list.append(model)          
        additional_data_index[label] = select_additional_data(x_train, binary_classifier_list, additional_data_size)
        
    # estimate additional clean data
    precision_additional_data = []
    number_additional_data = []
    for label in range(10):
        index = additional_data_index[label]
        true_positive_index = list(np.where(y_train_orig[:, label] == 1)[0])
        TP = len(list(set(index) & set(true_positive_index)))
        if len(index) == 0:
            precision_additional_data.append(0)
        else:
            precision_additional_data.append(TP / len(index))
        number_additional_data.append(len(index))
    print(precision_additional_data)
    print(number_additional_data)
# Out:
# iteration 0 label 0 index 0
# Epoch 1/30
# 100/100 [==============================] - 1s 7ms/step - loss: 0.2485 - acc: 0.5500
# Epoch 2/30
# 100/100 [==============================] - 0s 193us/step - loss: 0.2489 - acc: 0.5500
# Epoch 3/30
# 100/100 [==============================] - 0s 179us/step - loss: 0.2510 - acc: 0.5200
# Epoch 4/30
# 100/100 [==============================] - 0s 181us/step - loss: 0.2481 - acc: 0.5300
# Epoch 5/30
# 100/100 [==============================] - 0s 182us/step - loss: 0.2452 - acc: 0.6000
# Epoch 6/30
# 100/100 [==============================] - 0s 180us/step - loss: 0.2433 - acc: 0.4900
# Epoch 7/30
# 100/100 [==============================] - 0s 192us/step - loss: 0.2415 - acc: 0.4600
# Epoch 8/30
# 100/100 [==============================] - 0s 180us/step - loss: 0.2345 - acc: 0.5500
# Epoch 9/30
# 100/100 [==============================] - 0s 176us/step - loss: 0.2380 - acc: 0.5400
# Epoch 10/30
# 100/100 [==============================] - 0s 178us/step - loss: 0.2374 - acc: 0.5200
# Epoch 11/30
# 100/100 [==============================] - 0s 184us/step - loss: 0.2374 - acc: 0.5900
# Epoch 12/30
# 100/100 [==============================] - 0s 179us/step - loss: 0.2362 - acc: 0.5900
# Epoch 13/30
# 100/100 [==============================] - 0s 187us/step - loss: 0.2400 - acc: 0.5500
# iteration 0 label 0 index 1
# Epoch 1/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2424 - acc: 0.5200
# Epoch 2/30
# 100/100 [==============================] - 0s 196us/step - loss: 0.2491 - acc: 0.5000
# Epoch 3/30
# 100/100 [==============================] - 0s 194us/step - loss: 0.2433 - acc: 0.5700
# Epoch 4/30
# 100/100 [==============================] - 0s 182us/step - loss: 0.2432 - acc: 0.5500
# Epoch 5/30
# 100/100 [==============================] - 0s 184us/step - loss: 0.2273 - acc: 0.6600
# Epoch 6/30
# 100/100 [==============================] - 0s 181us/step - loss: 0.2468 - acc: 0.5400
# Epoch 7/30
# 100/100 [==============================] - 0s 182us/step - loss: 0.2304 - acc: 0.5500
# Epoch 8/30
# 100/100 [==============================] - 0s 183us/step - loss: 0.2261 - acc: 0.6200
# Epoch 9/30
# 100/100 [==============================] - 0s 187us/step - loss: 0.2201 - acc: 0.6600
# Epoch 10/30
# 100/100 [==============================] - 0s 186us/step - loss: 0.2170 - acc: 0.6400
# Epoch 11/30
# 100/100 [==============================] - 0s 179us/step - loss: 0.2093 - acc: 0.7000
# Epoch 12/30
# 100/100 [==============================] - 0s 190us/step - loss: 0.2100 - acc: 0.7100
# Epoch 13/30
# 100/100 [==============================] - 0s 184us/step - loss: 0.2095 - acc: 0.6500
# Epoch 14/30
# 100/100 [==============================] - 0s 187us/step - loss: 0.2009 - acc: 0.6600
# Epoch 15/30
# 100/100 [==============================] - 0s 180us/step - loss: 0.1972 - acc: 0.7300
# Epoch 16/30
# 100/100 [==============================] - 0s 187us/step - loss: 0.1903 - acc: 0.7100
# Epoch 17/30
# 100/100 [==============================] - 0s 193us/step - loss: 0.1813 - acc: 0.7400
# Epoch 18/30
# 100/100 [==============================] - 0s 201us/step - loss: 0.1731 - acc: 0.7500
# Epoch 19/30
# 100/100 [==============================] - 0s 182us/step - loss: 0.1753 - acc: 0.7500
# Epoch 20/30
# 100/100 [==============================] - 0s 190us/step - loss: 0.1726 - acc: 0.7200
# Epoch 21/30
# 100/100 [==============================] - 0s 186us/step - loss: 0.1690 - acc: 0.7400
# Epoch 22/30
# 100/100 [==============================] - 0s 190us/step - loss: 0.1635 - acc: 0.7500
# Epoch 23/30
# 100/100 [==============================] - 0s 185us/step - loss: 0.1843 - acc: 0.7400
# Epoch 24/30
# 100/100 [==============================] - 0s 193us/step - loss: 0.1588 - acc: 0.7600
# Epoch 25/30
# 100/100 [==============================] - 0s 187us/step - loss: 0.2033 - acc: 0.6600
# Epoch 26/30
# 100/100 [==============================] - 0s 186us/step - loss: 0.1542 - acc: 0.7700
# Epoch 27/30
# 100/100 [==============================] - 0s 182us/step - loss: 0.1583 - acc: 0.7800
# Epoch 28/30
# 100/100 [==============================] - 0s 187us/step - loss: 0.1581 - acc: 0.7800
# Epoch 29/30
# 100/100 [==============================] - 0s 184us/step - loss: 0.1660 - acc: 0.7800
# Epoch 30/30
# 100/100 [==============================] - 0s 184us/step - loss: 0.1569 - acc: 0.8300
# iteration 0 label 0 index 2
# Epoch 1/30
# 100/100 [==============================] - 1s 6ms/step - loss: 0.2493 - acc: 0.4800
# Epoch 2/30
# 100/100 [==============================] - 0s 185us/step - loss: 0.2467 - acc: 0.5000
# Epoch 3/30
# 100/100 [==============================] - 0s 188us/step - loss: 0.2468 - acc: 0.5400
# Epoch 4/30
# 100/100 [==============================] - 0s 188us/step - loss: 0.2462 - acc: 0.5300
# Epoch 5/30
# 100/100 [==============================] - 0s 185us/step - loss: 0.2435 - acc: 0.5100
# Epoch 6/30
# 100/100 [==============================] - 0s 195us/step - loss: 0.2350 - acc: 0.5900
# Epoch 7/30
# 100/100 [==============================] - 0s 198us/step - loss: 0.2383 - acc: 0.5500
# Epoch 8/30
# 100/100 [==============================] - 0s 203us/step - loss: 0.2279 - acc: 0.5900
# Epoch 9/30
# 100/100 [==============================] - 0s 195us/step - loss: 0.2242 - acc: 0.6500
# Epoch 10/30
# 100/100 [==============================] - 0s 189us/step - loss: 0.2363 - acc: 0.5800
# Epoch 11/30
# 100/100 [==============================] - 0s 183us/step - loss: 0.2279 - acc: 0.5900
# Epoch 12/30
# 100/100 [==============================] - 0s 188us/step - loss: 0.2337 - acc: 0.6000
# Epoch 13/30
# 100/100 [==============================] - 0s 186us/step - loss: 0.2266 - acc: 0.6400
# Epoch 14/30
# 100/100 [==============================] - 0s 182us/step - loss: 0.2324 - acc: 0.6100
# iteration 0 label 0 index 3
# Epoch 1/30
# 100/100 [==============================] - 1s 8ms/step - loss: 0.2564 - acc: 0.4800
# Epoch 2/30
# 100/100 [==============================] - 0s 203us/step - loss: 0.2475 - acc: 0.5700
# Epoch 3/30
# 100/100 [==============================] - 0s 180us/step - loss: 0.2400 - acc: 0.5900
# Epoch 4/30
# 100/100 [==============================] - 0s 183us/step - loss: 0.2432 - acc: 0.6400
# Epoch 5/30
# 100/100 [==============================] - 0s 179us/step - loss: 0.2403 - acc: 0.6300
# Epoch 6/30
# 100/100 [==============================] - 0s 184us/step - loss: 0.2424 - acc: 0.6100
# Epoch 7/30
# 100/100 [==============================] - 0s 185us/step - loss: 0.2419 - acc: 0.5700
# Epoch 8/30
# 100/100 [==============================] - 0s 189us/step - loss: 0.2349 - acc: 0.6400
# Epoch 9/30
# 100/100 [==============================] - 0s 190us/step - loss: 0.2404 - acc: 0.6300
# Epoch 10/30
# 100/100 [==============================] - 0s 214us/step - loss: 0.2238 - acc: 0.6500
# Epoch 11/30
# 100/100 [==============================] - 0s 210us/step - loss: 0.2302 - acc: 0.5400
# Epoch 12/30
# 100/100 [==============================] - 0s 187us/step - loss: 0.2256 - acc: 0.5800
# Epoch 13/30
# 100/100 [==============================] - 0s 185us/step - loss: 0.2176 - acc: 0.7200
# Epoch 14/30
# 100/100 [==============================] - 0s 195us/step - loss: 0.2200 - acc: 0.7000
# Epoch 15/30
# 100/100 [==============================] - 0s 185us/step - loss: 0.2251 - acc: 0.5600
# Epoch 16/30
# 100/100 [==============================] - 0s 196us/step - loss: 0.2093 - acc: 0.7300
# Epoch 17/30
# 100/100 [==============================] - 0s 193us/step - loss: 0.2052 - acc: 0.7300
# Epoch 18/30
# 100/100 [==============================] - 0s 184us/step - loss: 0.1990 - acc: 0.7400
# Epoch 19/30
# 100/100 [==============================] - 0s 187us/step - loss: 0.2038 - acc: 0.7200
# Epoch 20/30
# 100/100 [==============================] - 0s 183us/step - loss: 0.1920 - acc: 0.7300
# Epoch 21/30
# 100/100 [==============================] - 0s 181us/step - loss: 0.2201 - acc: 0.6400
# Epoch 22/30
# 100/100 [==============================] - 0s 189us/step - loss: 0.2020 - acc: 0.6500
# Epoch 23/30
# 100/100 [==============================] - 0s 197us/step - loss: 0.1849 - acc: 0.7400
# Epoch 24/30
# 100/100 [==============================] - 0s 203us/step - loss: 0.1867 - acc: 0.7300
# Epoch 25/30
# 100/100 [==============================] - 0s 198us/step - loss: 0.1793 - acc: 0.8100
# Epoch 26/30
# 100/100 [==============================] - 0s 198us/step - loss: 0.1826 - acc: 0.7400
# Epoch 27/30
# 100/100 [==============================] - 0s 225us/step - loss: 0.1878 - acc: 0.7000
# Epoch 28/30
# 100/100 [==============================] - 0s 208us/step - loss: 0.1635 - acc: 0.8200
# Epoch 29/30
# 100/100 [==============================] - 0s 218us/step - loss: 0.1696 - acc: 0.7500
# Epoch 30/30
# 100/100 [==============================] - 0s 199us/step - loss: 0.1530 - acc: 0.8100
# iteration 0 label 0 index 4
# Epoch 1/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.2518 - acc: 0.5200
# Epoch 2/30
# 100/100 [==============================] - 0s 261us/step - loss: 0.2463 - acc: 0.5100
# Epoch 3/30
# 100/100 [==============================] - 0s 267us/step - loss: 0.2483 - acc: 0.5100
# Epoch 4/30
# 100/100 [==============================] - 0s 301us/step - loss: 0.2438 - acc: 0.5000
# Epoch 5/30
# 100/100 [==============================] - 0s 322us/step - loss: 0.2431 - acc: 0.5100
# Epoch 6/30
# 100/100 [==============================] - 0s 377us/step - loss: 0.2445 - acc: 0.4900
# Epoch 7/30
# 100/100 [==============================] - 0s 284us/step - loss: 0.2383 - acc: 0.6500
# Epoch 8/30
# 100/100 [==============================] - 0s 282us/step - loss: 0.2333 - acc: 0.6500
# Epoch 9/30
# 100/100 [==============================] - 0s 316us/step - loss: 0.2315 - acc: 0.6600
# Epoch 10/30
# 100/100 [==============================] - 0s 309us/step - loss: 0.2245 - acc: 0.7500
# Epoch 11/30
# 100/100 [==============================] - 0s 256us/step - loss: 0.2182 - acc: 0.7200
# Epoch 12/30
# 100/100 [==============================] - 0s 282us/step - loss: 0.2246 - acc: 0.6500
# Epoch 13/30
# 100/100 [==============================] - 0s 263us/step - loss: 0.2073 - acc: 0.7100
# Epoch 14/30
# 100/100 [==============================] - 0s 265us/step - loss: 0.2416 - acc: 0.5500
# Epoch 15/30
# 100/100 [==============================] - 0s 264us/step - loss: 0.2158 - acc: 0.6800
# Epoch 16/30
# 100/100 [==============================] - 0s 256us/step - loss: 0.2401 - acc: 0.5800
# Epoch 17/30
# 100/100 [==============================] - 0s 371us/step - loss: 0.2112 - acc: 0.6500
# Epoch 18/30
# 100/100 [==============================] - 0s 435us/step - loss: 0.2092 - acc: 0.7000
# iteration 0 label 0 index 5
# Epoch 1/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.2567 - acc: 0.4400
# Epoch 2/30
# 100/100 [==============================] - 0s 189us/step - loss: 0.2427 - acc: 0.5300
# Epoch 3/30
# 100/100 [==============================] - 0s 193us/step - loss: 0.2464 - acc: 0.5200
# Epoch 4/30
# 100/100 [==============================] - 0s 203us/step - loss: 0.2369 - acc: 0.5200
# Epoch 5/30
# 100/100 [==============================] - 0s 189us/step - loss: 0.2369 - acc: 0.5500
# Epoch 6/30
# 100/100 [==============================] - 0s 199us/step - loss: 0.2404 - acc: 0.5900
# Epoch 7/30
# 100/100 [==============================] - 0s 189us/step - loss: 0.2330 - acc: 0.6300
# Epoch 8/30
# 100/100 [==============================] - 0s 199us/step - loss: 0.2343 - acc: 0.5800
# Epoch 9/30
# 100/100 [==============================] - 0s 198us/step - loss: 0.2277 - acc: 0.5900
# Epoch 10/30
# 100/100 [==============================] - 0s 194us/step - loss: 0.2195 - acc: 0.7100
# Epoch 11/30
# 100/100 [==============================] - 0s 204us/step - loss: 0.2250 - acc: 0.6600
# Epoch 12/30
# 100/100 [==============================] - 0s 215us/step - loss: 0.2138 - acc: 0.7100
# Epoch 13/30
# 100/100 [==============================] - 0s 201us/step - loss: 0.2020 - acc: 0.6700
# Epoch 14/30
# 100/100 [==============================] - 0s 205us/step - loss: 0.2305 - acc: 0.5900
# Epoch 15/30
# 100/100 [==============================] - 0s 190us/step - loss: 0.2136 - acc: 0.6500
# Epoch 16/30
# 100/100 [==============================] - 0s 184us/step - loss: 0.2170 - acc: 0.6600
# Epoch 17/30
# 100/100 [==============================] - 0s 187us/step - loss: 0.2007 - acc: 0.7000
# Epoch 18/30
# 100/100 [==============================] - 0s 189us/step - loss: 0.1820 - acc: 0.7200
# Epoch 19/30
# 100/100 [==============================] - 0s 198us/step - loss: 0.2003 - acc: 0.6600
# Epoch 20/30
# 100/100 [==============================] - 0s 202us/step - loss: 0.1800 - acc: 0.8000
# Epoch 21/30
# 100/100 [==============================] - 0s 208us/step - loss: 0.1907 - acc: 0.7500
# Epoch 22/30
# 100/100 [==============================] - 0s 194us/step - loss: 0.1763 - acc: 0.7600
# Epoch 23/30
# 100/100 [==============================] - 0s 218us/step - loss: 0.1868 - acc: 0.7000
# Epoch 24/30
# 100/100 [==============================] - 0s 197us/step - loss: 0.1751 - acc: 0.7800
# Epoch 25/30
# 100/100 [==============================] - 0s 233us/step - loss: 0.1747 - acc: 0.7800
# Epoch 26/30
# 100/100 [==============================] - 0s 212us/step - loss: 0.1549 - acc: 0.7900
# Epoch 27/30
# 100/100 [==============================] - 0s 205us/step - loss: 0.1831 - acc: 0.7200
# Epoch 28/30
# 100/100 [==============================] - 0s 234us/step - loss: 0.1637 - acc: 0.7700
# Epoch 29/30
# 100/100 [==============================] - 0s 192us/step - loss: 0.1428 - acc: 0.7900
# Epoch 30/30
# 100/100 [==============================] - 0s 187us/step - loss: 0.1410 - acc: 0.8100
# iteration 0 label 0 index 6
# Epoch 1/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.2573 - acc: 0.4500
# Epoch 2/30
# 100/100 [==============================] - 0s 187us/step - loss: 0.2480 - acc: 0.5500
# Epoch 3/30
# 100/100 [==============================] - 0s 185us/step - loss: 0.2437 - acc: 0.5900
# Epoch 4/30
# 100/100 [==============================] - 0s 185us/step - loss: 0.2428 - acc: 0.5500
# Epoch 5/30
# 100/100 [==============================] - 0s 184us/step - loss: 0.2447 - acc: 0.5500
# Epoch 6/30
# 100/100 [==============================] - 0s 182us/step - loss: 0.2407 - acc: 0.5900
# Epoch 7/30
# 100/100 [==============================] - 0s 185us/step - loss: 0.2417 - acc: 0.6000
# Epoch 8/30
# 100/100 [==============================] - 0s 186us/step - loss: 0.2415 - acc: 0.6000
# Epoch 9/30
# 100/100 [==============================] - 0s 185us/step - loss: 0.2298 - acc: 0.6700
# Epoch 10/30
# 100/100 [==============================] - 0s 185us/step - loss: 0.2320 - acc: 0.6100
# Epoch 11/30
# 100/100 [==============================] - 0s 185us/step - loss: 0.2242 - acc: 0.7100
# Epoch 12/30
# 100/100 [==============================] - 0s 228us/step - loss: 0.2397 - acc: 0.5800
# Epoch 13/30
# 100/100 [==============================] - 0s 185us/step - loss: 0.2293 - acc: 0.6100
# Epoch 14/30
# 100/100 [==============================] - 0s 186us/step - loss: 0.2274 - acc: 0.6600
# Epoch 15/30
# 100/100 [==============================] - 0s 183us/step - loss: 0.2234 - acc: 0.6200
# Epoch 16/30
# 100/100 [==============================] - 0s 183us/step - loss: 0.2085 - acc: 0.7400
# Epoch 17/30
# 100/100 [==============================] - 0s 185us/step - loss: 0.2146 - acc: 0.7600
# Epoch 18/30
# 100/100 [==============================] - 0s 186us/step - loss: 0.2109 - acc: 0.7200
# Epoch 19/30
# 100/100 [==============================] - 0s 189us/step - loss: 0.1952 - acc: 0.7800
# Epoch 20/30
# 100/100 [==============================] - 0s 187us/step - loss: 0.1928 - acc: 0.7600
# Epoch 21/30
# 100/100 [==============================] - 0s 193us/step - loss: 0.1900 - acc: 0.7800
# Epoch 22/30
# 100/100 [==============================] - 0s 194us/step - loss: 0.1808 - acc: 0.7400
# Epoch 23/30
# 100/100 [==============================] - 0s 184us/step - loss: 0.1798 - acc: 0.7500
# Epoch 24/30
# 100/100 [==============================] - 0s 230us/step - loss: 0.1678 - acc: 0.7800
# Epoch 25/30
# 100/100 [==============================] - 0s 189us/step - loss: 0.1709 - acc: 0.7900
# Epoch 26/30
# 100/100 [==============================] - 0s 189us/step - loss: 0.1585 - acc: 0.8100
# Epoch 27/30
# 100/100 [==============================] - 0s 180us/step - loss: 0.1522 - acc: 0.8100
# Epoch 28/30
# 100/100 [==============================] - 0s 187us/step - loss: 0.1624 - acc: 0.8000
# Epoch 29/30
# 100/100 [==============================] - 0s 254us/step - loss: 0.1662 - acc: 0.7400
# Epoch 30/30
# 100/100 [==============================] - 0s 196us/step - loss: 0.1430 - acc: 0.8500
# iteration 0 label 0 index 7
# Epoch 1/30
# 100/100 [==============================] - 1s 9ms/step - loss: 0.2478 - acc: 0.5500
# Epoch 2/30
# 100/100 [==============================] - 0s 202us/step - loss: 0.2461 - acc: 0.5500
# Epoch 3/30
# 100/100 [==============================] - 0s 198us/step - loss: 0.2501 - acc: 0.5200
# Epoch 4/30
# 100/100 [==============================] - 0s 193us/step - loss: 0.2457 - acc: 0.5200
# Epoch 5/30
# 100/100 [==============================] - 0s 189us/step - loss: 0.2464 - acc: 0.5800
# Epoch 6/30
# 100/100 [==============================] - 0s 190us/step - loss: 0.2445 - acc: 0.5800
# Epoch 7/30
# 100/100 [==============================] - 0s 191us/step - loss: 0.2273 - acc: 0.6700
# Epoch 8/30
# 100/100 [==============================] - 0s 196us/step - loss: 0.2437 - acc: 0.5700
# Epoch 9/30
# 100/100 [==============================] - 0s 189us/step - loss: 0.2367 - acc: 0.5500
# Epoch 10/30
# 100/100 [==============================] - 0s 182us/step - loss: 0.2317 - acc: 0.6800
# Epoch 11/30
# 100/100 [==============================] - 0s 186us/step - loss: 0.2319 - acc: 0.5900
# Epoch 12/30
# 100/100 [==============================] - 0s 189us/step - loss: 0.2354 - acc: 0.6100
# iteration 0 label 0 index 8
# Epoch 1/30
# 100/100 [==============================] - 1s 12ms/step - loss: 0.2447 - acc: 0.5400
# Epoch 2/30
# 100/100 [==============================] - 0s 205us/step - loss: 0.2474 - acc: 0.5100
# Epoch 3/30
# 100/100 [==============================] - 0s 244us/step - loss: 0.2358 - acc: 0.5800
# Epoch 4/30
# 100/100 [==============================] - 0s 236us/step - loss: 0.2365 - acc: 0.5600
# Epoch 5/30
# 100/100 [==============================] - 0s 222us/step - loss: 0.2372 - acc: 0.6300
# Epoch 6/30
# 100/100 [==============================] - 0s 205us/step - loss: 0.2441 - acc: 0.5900
# Epoch 7/30
# 100/100 [==============================] - 0s 290us/step - loss: 0.2275 - acc: 0.6400
# Epoch 8/30
# 100/100 [==============================] - 0s 236us/step - loss: 0.2221 - acc: 0.6600
# Epoch 9/30
# 100/100 [==============================] - 0s 213us/step - loss: 0.2194 - acc: 0.7000
# Epoch 10/30
# 100/100 [==============================] - 0s 230us/step - loss: 0.2168 - acc: 0.6900
# Epoch 11/30
# 100/100 [==============================] - 0s 275us/step - loss: 0.2132 - acc: 0.6800
# Epoch 12/30
# 100/100 [==============================] - 0s 240us/step - loss: 0.1984 - acc: 0.6900
# Epoch 13/30
# 100/100 [==============================] - 0s 250us/step - loss: 0.2163 - acc: 0.6200
# Epoch 14/30
# 100/100 [==============================] - 0s 243us/step - loss: 0.1856 - acc: 0.7200
# Epoch 15/30
# 100/100 [==============================] - 0s 236us/step - loss: 0.1631 - acc: 0.7700
# Epoch 16/30
# 100/100 [==============================] - 0s 305us/step - loss: 0.1892 - acc: 0.7400
# Epoch 17/30
# 100/100 [==============================] - 0s 213us/step - loss: 0.1861 - acc: 0.7200
# Epoch 18/30
# 100/100 [==============================] - 0s 225us/step - loss: 0.1714 - acc: 0.7500
# Epoch 19/30
# 100/100 [==============================] - 0s 223us/step - loss: 0.1680 - acc: 0.7100
# Epoch 20/30
# 100/100 [==============================] - 0s 241us/step - loss: 0.1756 - acc: 0.7600
# iteration 0 label 0 index 9
# Epoch 1/30
# 100/100 [==============================] - 1s 14ms/step - loss: 0.2589 - acc: 0.4500
# Epoch 2/30
# 100/100 [==============================] - 0s 222us/step - loss: 0.2509 - acc: 0.5300
# Epoch 3/30
# 100/100 [==============================] - 0s 214us/step - loss: 0.2441 - acc: 0.5300
# Epoch 4/30
# 100/100 [==============================] - 0s 206us/step - loss: 0.2456 - acc: 0.5300
# Epoch 5/30
# 100/100 [==============================] - 0s 224us/step - loss: 0.2437 - acc: 0.5100
# Epoch 6/30
# 100/100 [==============================] - 0s 211us/step - loss: 0.2388 - acc: 0.5800
# Epoch 7/30
# 100/100 [==============================] - 0s 220us/step - loss: 0.2329 - acc: 0.6400
# Epoch 8/30
# 100/100 [==============================] - 0s 213us/step - loss: 0.2328 - acc: 0.6600
# Epoch 9/30
# 100/100 [==============================] - 0s 245us/step - loss: 0.2408 - acc: 0.5300
# Epoch 10/30
# 100/100 [==============================] - 0s 238us/step - loss: 0.2504 - acc: 0.5400
# Epoch 11/30
# 100/100 [==============================] - 0s 240us/step - loss: 0.2198 - acc: 0.7100
# Epoch 12/30
# 100/100 [==============================] - 0s 239us/step - loss: 0.2253 - acc: 0.6200
# Epoch 13/30
# 100/100 [==============================] - 0s 275us/step - loss: 0.2281 - acc: 0.6500
# Epoch 14/30
# 100/100 [==============================] - 0s 275us/step - loss: 0.2305 - acc: 0.5700
# Epoch 15/30
# 100/100 [==============================] - 0s 305us/step - loss: 0.2313 - acc: 0.6000
# Epoch 16/30
# 100/100 [==============================] - 0s 267us/step - loss: 0.2157 - acc: 0.6800
# Epoch 17/30
# 100/100 [==============================] - 0s 288us/step - loss: 0.2070 - acc: 0.7600
# Epoch 18/30
# 100/100 [==============================] - 0s 349us/step - loss: 0.2074 - acc: 0.7300
# Epoch 19/30
# 100/100 [==============================] - 0s 267us/step - loss: 0.2084 - acc: 0.7300
# Epoch 20/30
# 100/100 [==============================] - 0s 463us/step - loss: 0.1940 - acc: 0.7600
# Epoch 21/30
# 100/100 [==============================] - 0s 336us/step - loss: 0.2026 - acc: 0.7200
# Epoch 22/30
# 100/100 [==============================] - 0s 285us/step - loss: 0.1946 - acc: 0.7900
# Epoch 23/30
# 100/100 [==============================] - 0s 279us/step - loss: 0.1887 - acc: 0.7000
# Epoch 24/30
# 100/100 [==============================] - 0s 293us/step - loss: 0.1901 - acc: 0.7200
# Epoch 25/30
# 100/100 [==============================] - 0s 335us/step - loss: 0.1831 - acc: 0.7200
# Epoch 26/30
# 100/100 [==============================] - 0s 406us/step - loss: 0.1666 - acc: 0.7800
# Epoch 27/30
# 100/100 [==============================] - 0s 366us/step - loss: 0.1794 - acc: 0.6900
# Epoch 28/30
# 100/100 [==============================] - 0s 366us/step - loss: 0.1602 - acc: 0.7400
# Epoch 29/30
# 100/100 [==============================] - 0s 486us/step - loss: 0.1684 - acc: 0.7900
# Epoch 30/30
# 100/100 [==============================] - 0s 446us/step - loss: 0.1520 - acc: 0.8000
# iteration 0 label 0 index 10
# Epoch 1/30
# 100/100 [==============================] - 1s 12ms/step - loss: 0.2494 - acc: 0.5100
# Epoch 2/30
# 100/100 [==============================] - 0s 346us/step - loss: 0.2451 - acc: 0.5700
# Epoch 3/30
# 100/100 [==============================] - 0s 221us/step - loss: 0.2411 - acc: 0.5400
# Epoch 4/30
# 100/100 [==============================] - 0s 207us/step - loss: 0.2494 - acc: 0.5100
# Epoch 5/30
# 100/100 [==============================] - 0s 222us/step - loss: 0.2372 - acc: 0.5400
# Epoch 6/30
# 100/100 [==============================] - 0s 200us/step - loss: 0.2375 - acc: 0.6100
# Epoch 7/30
# 100/100 [==============================] - 0s 218us/step - loss: 0.2302 - acc: 0.6300
# Epoch 8/30
# 100/100 [==============================] - 0s 254us/step - loss: 0.2289 - acc: 0.6500
# Epoch 9/30
# 100/100 [==============================] - 0s 236us/step - loss: 0.2310 - acc: 0.6600
# Epoch 10/30
# 100/100 [==============================] - 0s 196us/step - loss: 0.2230 - acc: 0.6900
# Epoch 11/30
# 100/100 [==============================] - 0s 231us/step - loss: 0.2238 - acc: 0.6600
# Epoch 12/30
# 100/100 [==============================] - 0s 225us/step - loss: 0.2114 - acc: 0.7100
# Epoch 13/30
# 100/100 [==============================] - 0s 206us/step - loss: 0.2147 - acc: 0.7100
# Epoch 14/30
# 100/100 [==============================] - 0s 191us/step - loss: 0.2148 - acc: 0.6200
# Epoch 15/30
# 100/100 [==============================] - 0s 195us/step - loss: 0.2137 - acc: 0.6300
# Epoch 16/30
# 100/100 [==============================] - 0s 238us/step - loss: 0.1976 - acc: 0.7400
# Epoch 17/30
# 100/100 [==============================] - 0s 201us/step - loss: 0.1963 - acc: 0.6900
# Epoch 18/30
# 100/100 [==============================] - 0s 206us/step - loss: 0.1934 - acc: 0.7200
# Epoch 19/30
# 100/100 [==============================] - 0s 194us/step - loss: 0.1887 - acc: 0.7000
# Epoch 20/30
# 100/100 [==============================] - 0s 217us/step - loss: 0.1964 - acc: 0.6800
# Epoch 21/30
# 100/100 [==============================] - 0s 355us/step - loss: 0.1902 - acc: 0.7200
# Epoch 22/30
# 100/100 [==============================] - 0s 895us/step - loss: 0.1740 - acc: 0.7400
# Epoch 23/30
# 100/100 [==============================] - 0s 319us/step - loss: 0.1904 - acc: 0.7100
# Epoch 24/30
# 100/100 [==============================] - 0s 277us/step - loss: 0.1996 - acc: 0.6900
# Epoch 25/30
# 100/100 [==============================] - 0s 422us/step - loss: 0.1612 - acc: 0.7900
# Epoch 26/30
# 100/100 [==============================] - 0s 275us/step - loss: 0.1657 - acc: 0.7700
# Epoch 27/30
# 100/100 [==============================] - 0s 350us/step - loss: 0.1626 - acc: 0.7800
# Epoch 28/30
# 100/100 [==============================] - 0s 275us/step - loss: 0.1565 - acc: 0.7800
# Epoch 29/30
# 100/100 [==============================] - 0s 310us/step - loss: 0.1575 - acc: 0.8000
# Epoch 30/30
# 100/100 [==============================] - 0s 335us/step - loss: 0.1630 - acc: 0.7700
# iteration 0 label 0 index 11
# Epoch 1/30
# 100/100 [==============================] - 1s 14ms/step - loss: 0.2504 - acc: 0.5600
# Epoch 2/30
# 100/100 [==============================] - 0s 911us/step - loss: 0.2477 - acc: 0.5200
# Epoch 3/30
# 100/100 [==============================] - 0s 905us/step - loss: 0.2385 - acc: 0.6000
# Epoch 4/30
# 100/100 [==============================] - 0s 888us/step - loss: 0.2408 - acc: 0.6100
# Epoch 5/30
# 100/100 [==============================] - 0s 759us/step - loss: 0.2375 - acc: 0.5900
# Epoch 6/30
# 100/100 [==============================] - 0s 881us/step - loss: 0.2411 - acc: 0.5600
# Epoch 7/30
# 100/100 [==============================] - 0s 512us/step - loss: 0.2313 - acc: 0.6000
# Epoch 8/30
# 100/100 [==============================] - 0s 201us/step - loss: 0.2334 - acc: 0.5600
# Epoch 9/30
# 100/100 [==============================] - 0s 221us/step - loss: 0.2226 - acc: 0.6700
# Epoch 10/30
# 100/100 [==============================] - 0s 204us/step - loss: 0.2279 - acc: 0.6200
# Epoch 11/30
# 100/100 [==============================] - 0s 201us/step - loss: 0.2241 - acc: 0.6500
# Epoch 12/30
# 100/100 [==============================] - 0s 191us/step - loss: 0.2234 - acc: 0.6300
# Epoch 13/30
# 100/100 [==============================] - 0s 199us/step - loss: 0.2053 - acc: 0.7200
# Epoch 14/30
# 100/100 [==============================] - 0s 199us/step - loss: 0.2147 - acc: 0.6600
# Epoch 15/30
# 100/100 [==============================] - 0s 201us/step - loss: 0.2049 - acc: 0.6700
# Epoch 16/30
# 100/100 [==============================] - 0s 194us/step - loss: 0.2226 - acc: 0.5900
# Epoch 17/30
# 100/100 [==============================] - 0s 196us/step - loss: 0.2001 - acc: 0.6600
# Epoch 18/30
# 100/100 [==============================] - 0s 193us/step - loss: 0.1888 - acc: 0.7100
# Epoch 19/30
# 100/100 [==============================] - 0s 197us/step - loss: 0.1743 - acc: 0.7600
# Epoch 20/30
# 100/100 [==============================] - 0s 197us/step - loss: 0.1777 - acc: 0.7000
# Epoch 21/30
# 100/100 [==============================] - 0s 216us/step - loss: 0.1630 - acc: 0.8000
# Epoch 22/30
# 100/100 [==============================] - 0s 203us/step - loss: 0.1724 - acc: 0.7400
# Epoch 23/30
# 100/100 [==============================] - 0s 231us/step - loss: 0.1658 - acc: 0.7100
# Epoch 24/30
# 100/100 [==============================] - 0s 194us/step - loss: 0.1693 - acc: 0.7500
# Epoch 25/30
# 100/100 [==============================] - 0s 187us/step - loss: 0.1668 - acc: 0.7300
# Epoch 26/30
# 100/100 [==============================] - 0s 192us/step - loss: 0.1569 - acc: 0.7700
# Epoch 27/30
# 100/100 [==============================] - 0s 194us/step - loss: 0.1678 - acc: 0.7800
# Epoch 28/30
# 100/100 [==============================] - 0s 197us/step - loss: 0.1735 - acc: 0.7300
# Epoch 29/30
# 100/100 [==============================] - 0s 199us/step - loss: 0.1623 - acc: 0.7700
# Epoch 30/30
# 100/100 [==============================] - 0s 200us/step - loss: 0.1489 - acc: 0.8100
# iteration 0 label 0 index 12
# Epoch 1/30
# 100/100 [==============================] - 1s 15ms/step - loss: 0.2436 - acc: 0.5900
# Epoch 2/30
# 100/100 [==============================] - 0s 273us/step - loss: 0.2495 - acc: 0.5100
# Epoch 3/30
# 100/100 [==============================] - 0s 255us/step - loss: 0.2478 - acc: 0.4800
# Epoch 4/30
# 100/100 [==============================] - 0s 249us/step - loss: 0.2528 - acc: 0.4700
# Epoch 5/30
# 100/100 [==============================] - 0s 248us/step - loss: 0.2463 - acc: 0.5000
# Epoch 6/30
# 100/100 [==============================] - 0s 238us/step - loss: 0.2385 - acc: 0.6300
# Epoch 7/30
# 100/100 [==============================] - 0s 227us/step - loss: 0.2399 - acc: 0.5800
# Epoch 8/30
# 100/100 [==============================] - 0s 218us/step - loss: 0.2382 - acc: 0.5200
# Epoch 9/30
# 100/100 [==============================] - 0s 226us/step - loss: 0.2337 - acc: 0.5500
# Epoch 10/30
# 100/100 [==============================] - 0s 216us/step - loss: 0.2326 - acc: 0.5700
# Epoch 11/30
# 100/100 [==============================] - 0s 223us/step - loss: 0.2229 - acc: 0.6200
# Epoch 12/30
# 100/100 [==============================] - 0s 226us/step - loss: 0.2108 - acc: 0.7600
# Epoch 13/30
# 100/100 [==============================] - 0s 227us/step - loss: 0.2187 - acc: 0.6000
# Epoch 14/30
# 100/100 [==============================] - 0s 243us/step - loss: 0.2025 - acc: 0.7100
# Epoch 15/30
# 100/100 [==============================] - 0s 299us/step - loss: 0.2042 - acc: 0.7000
# Epoch 16/30
# 100/100 [==============================] - 0s 246us/step - loss: 0.1905 - acc: 0.7500
# Epoch 17/30
# 100/100 [==============================] - 0s 249us/step - loss: 0.1859 - acc: 0.7700
# Epoch 18/30
# 100/100 [==============================] - 0s 244us/step - loss: 0.1754 - acc: 0.8100
# Epoch 19/30
# 100/100 [==============================] - 0s 268us/step - loss: 0.2053 - acc: 0.6400
# Epoch 20/30
# 100/100 [==============================] - 0s 255us/step - loss: 0.2113 - acc: 0.6500
# Epoch 21/30
# 100/100 [==============================] - 0s 271us/step - loss: 0.1843 - acc: 0.7400
# Epoch 22/30
# 100/100 [==============================] - 0s 235us/step - loss: 0.1977 - acc: 0.6800
# Epoch 23/30
# 100/100 [==============================] - 0s 250us/step - loss: 0.1930 - acc: 0.7200
# iteration 0 label 0 index 13
# Epoch 1/30
# 100/100 [==============================] - 2s 17ms/step - loss: 0.2525 - acc: 0.4300
# Epoch 2/30
# 100/100 [==============================] - 0s 403us/step - loss: 0.2361 - acc: 0.5600
# Epoch 3/30
# 100/100 [==============================] - 0s 250us/step - loss: 0.2482 - acc: 0.5100
# Epoch 4/30
# 100/100 [==============================] - 0s 325us/step - loss: 0.2430 - acc: 0.5400
# Epoch 5/30
# 100/100 [==============================] - 0s 312us/step - loss: 0.2458 - acc: 0.5100
# Epoch 6/30
# 100/100 [==============================] - 0s 426us/step - loss: 0.2390 - acc: 0.5400
# Epoch 7/30
# 100/100 [==============================] - 0s 546us/step - loss: 0.2377 - acc: 0.6000
# iteration 0 label 0 index 14
# Epoch 1/30
# 100/100 [==============================] - 2s 18ms/step - loss: 0.2486 - acc: 0.5300
# Epoch 2/30
# 100/100 [==============================] - 0s 238us/step - loss: 0.2497 - acc: 0.4900
# Epoch 3/30
# 100/100 [==============================] - 0s 206us/step - loss: 0.2478 - acc: 0.5200
# Epoch 4/30
# 100/100 [==============================] - 0s 195us/step - loss: 0.2443 - acc: 0.4900
# Epoch 5/30
# 100/100 [==============================] - 0s 202us/step - loss: 0.2449 - acc: 0.5100
# Epoch 6/30
# 100/100 [==============================] - 0s 195us/step - loss: 0.2421 - acc: 0.5600
# Epoch 7/30
# 100/100 [==============================] - 0s 197us/step - loss: 0.2304 - acc: 0.6700
# Epoch 8/30
# 100/100 [==============================] - 0s 209us/step - loss: 0.2251 - acc: 0.6800
# Epoch 9/30
# 100/100 [==============================] - 0s 211us/step - loss: 0.2229 - acc: 0.7000
# Epoch 10/30
# 100/100 [==============================] - 0s 196us/step - loss: 0.2150 - acc: 0.6900
# Epoch 11/30
# 100/100 [==============================] - 0s 198us/step - loss: 0.2104 - acc: 0.7100
# Epoch 12/30
# 100/100 [==============================] - 0s 206us/step - loss: 0.1896 - acc: 0.8100
# Epoch 13/30
# 100/100 [==============================] - 0s 215us/step - loss: 0.1934 - acc: 0.7100
# Epoch 14/30
# 100/100 [==============================] - 0s 206us/step - loss: 0.1826 - acc: 0.7000
# Epoch 15/30
# 100/100 [==============================] - 0s 199us/step - loss: 0.1757 - acc: 0.7300
# Epoch 16/30
# 100/100 [==============================] - 0s 200us/step - loss: 0.1700 - acc: 0.7900
# Epoch 17/30
# 100/100 [==============================] - 0s 201us/step - loss: 0.1737 - acc: 0.7500
# Epoch 18/30
# 100/100 [==============================] - 0s 217us/step - loss: 0.2087 - acc: 0.6900
# Epoch 19/30
# 100/100 [==============================] - 0s 211us/step - loss: 0.1790 - acc: 0.7700
# Epoch 20/30
# 100/100 [==============================] - 0s 201us/step - loss: 0.1723 - acc: 0.7700
# Epoch 21/30
# 100/100 [==============================] - 0s 202us/step - loss: 0.1857 - acc: 0.7100
# iteration 0 label 0 index 15
# Epoch 1/30
# 100/100 [==============================] - 2s 17ms/step - loss: 0.2502 - acc: 0.5600
# Epoch 2/30
# 100/100 [==============================] - 0s 222us/step - loss: 0.2508 - acc: 0.4800
# Epoch 3/30
# 100/100 [==============================] - 0s 236us/step - loss: 0.2448 - acc: 0.5400
# Epoch 4/30
# 100/100 [==============================] - 0s 247us/step - loss: 0.2399 - acc: 0.6300
# Epoch 5/30
# 100/100 [==============================] - 0s 247us/step - loss: 0.2408 - acc: 0.6100
# Epoch 6/30
# 100/100 [==============================] - 0s 216us/step - loss: 0.2357 - acc: 0.6500
# Epoch 7/30
# 100/100 [==============================] - 0s 192us/step - loss: 0.2373 - acc: 0.6000
# Epoch 8/30
# 100/100 [==============================] - 0s 205us/step - loss: 0.2338 - acc: 0.5900
# Epoch 9/30
# 100/100 [==============================] - 0s 221us/step - loss: 0.2261 - acc: 0.6700
# Epoch 10/30
# 100/100 [==============================] - 0s 218us/step - loss: 0.2204 - acc: 0.6600
# Epoch 11/30
# 100/100 [==============================] - 0s 308us/step - loss: 0.2173 - acc: 0.7100
# Epoch 12/30
# 100/100 [==============================] - 0s 268us/step - loss: 0.2204 - acc: 0.6700
# Epoch 13/30
# 100/100 [==============================] - 0s 205us/step - loss: 0.2053 - acc: 0.7100
# Epoch 14/30
# 100/100 [==============================] - 0s 202us/step - loss: 0.1993 - acc: 0.7000
# Epoch 15/30
# 100/100 [==============================] - 0s 193us/step - loss: 0.1862 - acc: 0.7700
# Epoch 16/30
# 100/100 [==============================] - 0s 204us/step - loss: 0.2057 - acc: 0.7000
# Epoch 17/30
# 100/100 [==============================] - 0s 203us/step - loss: 0.2008 - acc: 0.6600
# Epoch 18/30
# 100/100 [==============================] - 0s 192us/step - loss: 0.1899 - acc: 0.7200
# Epoch 19/30
# 100/100 [==============================] - 0s 193us/step - loss: 0.1861 - acc: 0.7400
# Epoch 20/30
# 100/100 [==============================] - 0s 193us/step - loss: 0.1859 - acc: 0.7100
# Epoch 21/30
# 100/100 [==============================] - 0s 193us/step - loss: 0.1811 - acc: 0.7200
# Epoch 22/30
# 100/100 [==============================] - 0s 197us/step - loss: 0.1650 - acc: 0.7800
# Epoch 23/30
# 100/100 [==============================] - 0s 197us/step - loss: 0.1917 - acc: 0.7200
# Epoch 24/30
# 100/100 [==============================] - 0s 197us/step - loss: 0.1826 - acc: 0.7400
# Epoch 25/30
# 100/100 [==============================] - 0s 206us/step - loss: 0.1910 - acc: 0.7600
# Epoch 26/30
# 100/100 [==============================] - 0s 196us/step - loss: 0.2188 - acc: 0.6600
# Epoch 27/30
# 100/100 [==============================] - 0s 194us/step - loss: 0.1664 - acc: 0.8000
# iteration 0 label 0 index 16
# Epoch 1/30
# 100/100 [==============================] - 2s 18ms/step - loss: 0.2498 - acc: 0.4700
# Epoch 2/30
# 100/100 [==============================] - 0s 279us/step - loss: 0.2465 - acc: 0.5800
# Epoch 3/30
# 100/100 [==============================] - 0s 238us/step - loss: 0.2516 - acc: 0.4700
# Epoch 4/30
# 100/100 [==============================] - 0s 274us/step - loss: 0.2494 - acc: 0.5300
# Epoch 5/30
# 100/100 [==============================] - 0s 215us/step - loss: 0.2393 - acc: 0.6200
# Epoch 6/30
# 100/100 [==============================] - 0s 275us/step - loss: 0.2473 - acc: 0.5500
# Epoch 7/30
# 100/100 [==============================] - 0s 244us/step - loss: 0.2399 - acc: 0.6200
# Epoch 8/30
# 100/100 [==============================] - 0s 231us/step - loss: 0.2438 - acc: 0.5300
# Epoch 9/30
# 100/100 [==============================] - 0s 228us/step - loss: 0.2352 - acc: 0.6800
# Epoch 10/30
# 100/100 [==============================] - 0s 217us/step - loss: 0.2249 - acc: 0.6600
# Epoch 11/30
# 100/100 [==============================] - 0s 248us/step - loss: 0.2262 - acc: 0.6900
# Epoch 12/30
# 100/100 [==============================] - 0s 278us/step - loss: 0.2233 - acc: 0.6600
# Epoch 13/30
# 100/100 [==============================] - 0s 260us/step - loss: 0.2332 - acc: 0.6400
# Epoch 14/30
# 100/100 [==============================] - 0s 267us/step - loss: 0.2113 - acc: 0.6500
# Epoch 15/30
# 100/100 [==============================] - 0s 263us/step - loss: 0.1982 - acc: 0.7700
# Epoch 16/30
# 100/100 [==============================] - 0s 253us/step - loss: 0.1944 - acc: 0.7500
# Epoch 17/30
# 100/100 [==============================] - 0s 254us/step - loss: 0.1840 - acc: 0.7300
# Epoch 18/30
# 100/100 [==============================] - 0s 244us/step - loss: 0.1894 - acc: 0.7000
# Epoch 19/30
# 100/100 [==============================] - 0s 226us/step - loss: 0.1762 - acc: 0.7600
# Epoch 20/30
# 100/100 [==============================] - 0s 222us/step - loss: 0.1716 - acc: 0.7600
# Epoch 21/30
# 100/100 [==============================] - 0s 227us/step - loss: 0.1801 - acc: 0.7100
# Epoch 22/30
# 100/100 [==============================] - 0s 201us/step - loss: 0.1638 - acc: 0.7200
# Epoch 23/30
# 100/100 [==============================] - 0s 232us/step - loss: 0.1672 - acc: 0.7700
# Epoch 24/30
# 100/100 [==============================] - 0s 236us/step - loss: 0.1580 - acc: 0.8000
# Epoch 25/30
# 100/100 [==============================] - 0s 223us/step - loss: 0.1761 - acc: 0.7500
# Epoch 26/30
# 100/100 [==============================] - 0s 250us/step - loss: 0.1554 - acc: 0.7900
# Epoch 27/30
# 100/100 [==============================] - 0s 254us/step - loss: 0.1390 - acc: 0.8500
# Epoch 28/30
# 100/100 [==============================] - 0s 296us/step - loss: 0.1531 - acc: 0.8000
# Epoch 29/30
# 100/100 [==============================] - 0s 250us/step - loss: 0.1474 - acc: 0.8400
# Epoch 30/30
# 100/100 [==============================] - 0s 278us/step - loss: 0.1660 - acc: 0.7200
# iteration 0 label 0 index 17
# Epoch 1/30
# 100/100 [==============================] - 2s 24ms/step - loss: 0.2447 - acc: 0.5700
# Epoch 2/30
# 100/100 [==============================] - 0s 222us/step - loss: 0.2471 - acc: 0.5100
# Epoch 3/30
# 100/100 [==============================] - 0s 215us/step - loss: 0.2376 - acc: 0.6000
# Epoch 4/30
# 100/100 [==============================] - 0s 206us/step - loss: 0.2347 - acc: 0.6300
# Epoch 5/30
# 100/100 [==============================] - 0s 230us/step - loss: 0.2323 - acc: 0.6100
# Epoch 6/30
# 100/100 [==============================] - 0s 199us/step - loss: 0.2254 - acc: 0.6300
# Epoch 7/30
# 100/100 [==============================] - 0s 219us/step - loss: 0.2235 - acc: 0.6200
# Epoch 8/30
# 100/100 [==============================] - 0s 217us/step - loss: 0.2231 - acc: 0.7100
# Epoch 9/30
# 100/100 [==============================] - 0s 218us/step - loss: 0.2352 - acc: 0.5500
# Epoch 10/30
# 100/100 [==============================] - 0s 225us/step - loss: 0.2120 - acc: 0.6900
# Epoch 11/30
# 100/100 [==============================] - 0s 218us/step - loss: 0.2102 - acc: 0.6900
# Epoch 12/30
# 100/100 [==============================] - 0s 208us/step - loss: 0.2125 - acc: 0.6700
# Epoch 13/30
# 100/100 [==============================] - 0s 203us/step - loss: 0.2042 - acc: 0.7300
# Epoch 14/30
# 100/100 [==============================] - 0s 195us/step - loss: 0.1868 - acc: 0.7700
# Epoch 15/30
# 100/100 [==============================] - 0s 193us/step - loss: 0.1854 - acc: 0.7300
# Epoch 16/30
# 100/100 [==============================] - 0s 197us/step - loss: 0.2011 - acc: 0.6900
# Epoch 17/30
# 100/100 [==============================] - 0s 192us/step - loss: 0.1786 - acc: 0.7600
# Epoch 18/30
# 100/100 [==============================] - 0s 199us/step - loss: 0.1716 - acc: 0.7800
# Epoch 19/30
# 100/100 [==============================] - 0s 195us/step - loss: 0.1714 - acc: 0.7800
# Epoch 20/30
# 100/100 [==============================] - 0s 200us/step - loss: 0.1763 - acc: 0.7700
# Epoch 21/30
# 100/100 [==============================] - 0s 200us/step - loss: 0.1705 - acc: 0.7600
# Epoch 22/30
# 100/100 [==============================] - 0s 196us/step - loss: 0.1756 - acc: 0.7400
# Epoch 23/30
# 100/100 [==============================] - 0s 200us/step - loss: 0.1619 - acc: 0.7600
# Epoch 24/30
# 100/100 [==============================] - 0s 196us/step - loss: 0.1522 - acc: 0.8100
# Epoch 25/30
# 100/100 [==============================] - 0s 193us/step - loss: 0.1533 - acc: 0.8000
# Epoch 26/30
# 100/100 [==============================] - 0s 192us/step - loss: 0.1613 - acc: 0.8100
# Epoch 27/30
# 100/100 [==============================] - 0s 190us/step - loss: 0.1661 - acc: 0.7900
# Epoch 28/30
# 100/100 [==============================] - 0s 193us/step - loss: 0.1783 - acc: 0.7000
# Epoch 29/30
# 100/100 [==============================] - 0s 193us/step - loss: 0.1481 - acc: 0.7900
# Epoch 30/30
# 100/100 [==============================] - 0s 192us/step - loss: 0.1810 - acc: 0.7300
# iteration 0 label 0 index 18
# Epoch 1/30
# 100/100 [==============================] - 2s 20ms/step - loss: 0.2516 - acc: 0.4800
# Epoch 2/30
# 100/100 [==============================] - 0s 205us/step - loss: 0.2447 - acc: 0.5800
# Epoch 3/30
# 100/100 [==============================] - 0s 202us/step - loss: 0.2492 - acc: 0.5100
# Epoch 4/30
# 100/100 [==============================] - 0s 230us/step - loss: 0.2396 - acc: 0.5500
# Epoch 5/30
# 100/100 [==============================] - 0s 215us/step - loss: 0.2407 - acc: 0.5200
# Epoch 6/30
# 100/100 [==============================] - 0s 236us/step - loss: 0.2423 - acc: 0.5200
# Epoch 7/30
# 100/100 [==============================] - 0s 210us/step - loss: 0.2406 - acc: 0.5100
# Epoch 8/30
# 100/100 [==============================] - 0s 203us/step - loss: 0.2384 - acc: 0.5200
# Epoch 9/30
# 100/100 [==============================] - 0s 228us/step - loss: 0.2378 - acc: 0.5100
# Epoch 10/30
# 100/100 [==============================] - 0s 234us/step - loss: 0.2266 - acc: 0.6500
# Epoch 11/30
# 100/100 [==============================] - 0s 226us/step - loss: 0.2480 - acc: 0.5700
# Epoch 12/30
# 100/100 [==============================] - 0s 229us/step - loss: 0.2407 - acc: 0.5600
# Epoch 13/30
# 100/100 [==============================] - 0s 232us/step - loss: 0.2190 - acc: 0.7300
# Epoch 14/30
# 100/100 [==============================] - 0s 256us/step - loss: 0.2223 - acc: 0.6300
# Epoch 15/30
# 100/100 [==============================] - 0s 244us/step - loss: 0.2283 - acc: 0.5900
# Epoch 16/30
# 100/100 [==============================] - 0s 225us/step - loss: 0.2271 - acc: 0.6000
# Epoch 17/30
# 100/100 [==============================] - 0s 232us/step - loss: 0.2337 - acc: 0.6200
# Epoch 18/30
# 100/100 [==============================] - 0s 211us/step - loss: 0.2202 - acc: 0.7100
# iteration 0 label 0 index 19
# Epoch 1/30
# 100/100 [==============================] - 2s 22ms/step - loss: 0.2498 - acc: 0.5400
# Epoch 2/30
# 100/100 [==============================] - 0s 249us/step - loss: 0.2461 - acc: 0.5400
# Epoch 3/30
# 100/100 [==============================] - 0s 250us/step - loss: 0.2489 - acc: 0.4900
# Epoch 4/30
# 100/100 [==============================] - 0s 266us/step - loss: 0.2526 - acc: 0.4900
# Epoch 5/30
# 100/100 [==============================] - 0s 245us/step - loss: 0.2456 - acc: 0.5300
# Epoch 6/30
# 100/100 [==============================] - 0s 234us/step - loss: 0.2386 - acc: 0.6000
# Epoch 7/30
# 100/100 [==============================] - 0s 258us/step - loss: 0.2429 - acc: 0.5200
# Epoch 8/30
# 100/100 [==============================] - 0s 244us/step - loss: 0.2376 - acc: 0.6100
# Epoch 9/30
# 100/100 [==============================] - 0s 273us/step - loss: 0.2358 - acc: 0.6600
# Epoch 10/30
# 100/100 [==============================] - 0s 257us/step - loss: 0.2286 - acc: 0.7000
# Epoch 11/30
# 100/100 [==============================] - 0s 256us/step - loss: 0.2307 - acc: 0.6200
# Epoch 12/30
# 100/100 [==============================] - 0s 263us/step - loss: 0.2301 - acc: 0.6000
# Epoch 13/30
# 100/100 [==============================] - 0s 237us/step - loss: 0.2138 - acc: 0.7000
# Epoch 14/30
# 100/100 [==============================] - 0s 236us/step - loss: 0.2104 - acc: 0.7000
# Epoch 15/30
# 100/100 [==============================] - 0s 221us/step - loss: 0.1962 - acc: 0.7500
# Epoch 16/30
# 100/100 [==============================] - 0s 227us/step - loss: 0.2071 - acc: 0.6500
# Epoch 17/30
# 100/100 [==============================] - 0s 230us/step - loss: 0.1933 - acc: 0.7700
# Epoch 18/30
# 100/100 [==============================] - 0s 245us/step - loss: 0.1859 - acc: 0.7700
# Epoch 19/30
# 100/100 [==============================] - 0s 251us/step - loss: 0.1765 - acc: 0.7400
# Epoch 20/30
# 100/100 [==============================] - 0s 241us/step - loss: 0.1780 - acc: 0.7600
# Epoch 21/30
# 100/100 [==============================] - 0s 229us/step - loss: 0.1624 - acc: 0.7800
# Epoch 22/30
# 100/100 [==============================] - 0s 251us/step - loss: 0.1820 - acc: 0.7000
# Epoch 23/30
# 100/100 [==============================] - 0s 236us/step - loss: 0.1437 - acc: 0.8000
# Epoch 24/30
# 100/100 [==============================] - 0s 245us/step - loss: 0.1691 - acc: 0.7900
# Epoch 25/30
# 100/100 [==============================] - 0s 250us/step - loss: 0.1722 - acc: 0.7200
# Epoch 26/30
# 100/100 [==============================] - 0s 225us/step - loss: 0.1534 - acc: 0.7800
# Epoch 27/30
# 100/100 [==============================] - 0s 236us/step - loss: 0.1362 - acc: 0.8100
# Epoch 28/30
# 100/100 [==============================] - 0s 230us/step - loss: 0.1316 - acc: 0.8300
# Epoch 29/30
# 100/100 [==============================] - 0s 234us/step - loss: 0.1319 - acc: 0.8200
# Epoch 30/30
# 100/100 [==============================] - 0s 235us/step - loss: 0.1743 - acc: 0.7600
# iteration 0 label 0 index 20
# Epoch 1/30
# 100/100 [==============================] - 2s 21ms/step - loss: 0.2553 - acc: 0.4600
# Epoch 2/30
# 100/100 [==============================] - 0s 210us/step - loss: 0.2516 - acc: 0.5100
# Epoch 3/30
# 100/100 [==============================] - 0s 217us/step - loss: 0.2480 - acc: 0.5200
# Epoch 4/30
# 100/100 [==============================] - 0s 207us/step - loss: 0.2442 - acc: 0.6000
# Epoch 5/30
# 100/100 [==============================] - 0s 231us/step - loss: 0.2439 - acc: 0.6400
# Epoch 6/30
# 100/100 [==============================] - 0s 226us/step - loss: 0.2440 - acc: 0.6100
# Epoch 7/30
# 100/100 [==============================] - 0s 229us/step - loss: 0.2401 - acc: 0.6200
# Epoch 8/30
# 100/100 [==============================] - 0s 207us/step - loss: 0.2331 - acc: 0.7100
# Epoch 9/30
# 100/100 [==============================] - 0s 214us/step - loss: 0.2316 - acc: 0.6800
# Epoch 10/30
# 100/100 [==============================] - 0s 222us/step - loss: 0.2365 - acc: 0.6100
# Epoch 11/30
# 100/100 [==============================] - 0s 223us/step - loss: 0.2284 - acc: 0.6200
# Epoch 12/30
# 100/100 [==============================] - 0s 199us/step - loss: 0.2337 - acc: 0.5900
# Epoch 13/30
# 100/100 [==============================] - 0s 213us/step - loss: 0.2556 - acc: 0.5000
# Epoch 14/30
# 100/100 [==============================] - 0s 217us/step - loss: 0.2560 - acc: 0.5000
# Epoch 15/30
# 100/100 [==============================] - 0s 210us/step - loss: 0.2359 - acc: 0.5300
# Epoch 16/30
# 100/100 [==============================] - 0s 201us/step - loss: 0.2332 - acc: 0.5800
# iteration 0 label 0 index 21
